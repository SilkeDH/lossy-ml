# %% [markdown]
# ## Model 4
#
# This model will tell us if the number of parameters are the ones responsible for the output gotten in model 3. The compression ratio will stay the same, strides/filter size as well but we will now add more layers. We will have in total as much parameters as in model 2.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from collections import OrderedDict
from DataLoader import DataGenerator

# %%
# %load_ext tensorboard
model = models.Sequential()
model.add(layers.Conv3D(5, (4, 4, 4), activation='relu', strides=2, input_shape=(24, 40, 40, 1), padding="same", data_format = "channels_last"))
model.add(layers.Conv3D(5, (4, 4, 4), strides=1, padding="same", activation='relu'))
model.add(layers.Conv3D(10, (4, 4, 4), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3D(10, (4, 4, 4), strides=1, padding="same", activation='relu'))
model.add(layers.Conv3D(10, (4, 4, 4), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(5, (4, 4, 4), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3D(5, (4, 4, 4), strides=1, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(5, (4, 4, 4), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3D(1, (4, 4, 4), strides=1, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(1, (4, 4, 4), strides=2, padding="same", activation = None))
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_14 (Conv3D)           (None, 12, 20, 20, 5)     325
# _________________________________________________________________
# conv3d_15 (Conv3D)           (None, 12, 20, 20, 5)     1605
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 6, 10, 10, 10)     3210
# _________________________________________________________________
# conv3d_17 (Conv3D)           (None, 6, 10, 10, 10)     6410
# _________________________________________________________________
# conv3d_18 (Conv3D)           (None, 3, 5, 5, 10)       6410
# _________________________________________________________________
# conv3d_transpose_6 (Conv3DTr (None, 6, 10, 10, 5)      3205
# _________________________________________________________________
# conv3d_19 (Conv3D)           (None, 6, 10, 10, 5)      1605
# _________________________________________________________________
# conv3d_transpose_7 (Conv3DTr (None, 12, 20, 20, 5)     1605
# _________________________________________________________________
# conv3d_20 (Conv3D)           (None, 12, 20, 20, 1)     321
# _________________________________________________________________
# conv3d_transpose_8 (Conv3DTr (None, 24, 40, 40, 1)     65
# =================================================================
# Total params: 24,761
# Trainable params: 24,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.MeanSquaredError())

# %%
months = 10
files = set('/lsdf/kit/scc/projects/abcde/1979/0'+str(i)+'/ERA5.pl.temperature.nc' for i in range(1,months))
z_train = xr.open_mfdataset(files, combine='by_coords')

bs=10 # batch size (from paper above)
dic = OrderedDict({'t': 1})  # Choosing first pressure level from variable temperature.
chunk_time = 24

#Define train and test datasets.
dg_train = DataGenerator(z_train.sel(time=slice('1979'), longitude=slice(6,15.75), latitude=slice(55.5,45.75)), dic, chunk_time, batch_size=bs, load=True, shuffle=True)
# Out:
# Loading data into RAM

# %%
# Using tensorboard.
import datetime
log_dir = "logs/fit/model4"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
history = model.fit(dg_train, validation_data = dg_train, epochs=200, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/200
#  2/28 [=>............................] - ETA: 1s - loss: 1.0897WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0057s vs `on_train_batch_end` time: 0.0747s). Check your callbacks.
# 28/28 [==============================] - 1s 22ms/step - loss: 0.9861 - val_loss: 0.9858
# Epoch 2/200
# 28/28 [==============================] - 0s 13ms/step - loss: 1.0303 - val_loss: 1.0126
# Epoch 3/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.9795 - val_loss: 0.9644
# Epoch 4/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.9703 - val_loss: 0.9590
# Epoch 5/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.9008 - val_loss: 0.8971
# Epoch 6/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.8762 - val_loss: 0.8602
# Epoch 7/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.9355 - val_loss: 0.9277
# Epoch 8/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.8926 - val_loss: 0.8800
# Epoch 9/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.8944 - val_loss: 0.8816
# Epoch 10/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.8666 - val_loss: 0.8687
# Epoch 11/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.8100 - val_loss: 0.7979
# Epoch 12/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.9066 - val_loss: 0.8951
# Epoch 13/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.8211 - val_loss: 0.8186
# Epoch 14/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.7761 - val_loss: 0.7664
# Epoch 15/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.7777 - val_loss: 0.7680
# Epoch 16/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.8226 - val_loss: 0.8114
# Epoch 17/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.7344 - val_loss: 0.7116
# Epoch 18/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.7354 - val_loss: 0.7084
# Epoch 19/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.7583 - val_loss: 0.7337
# Epoch 20/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6944 - val_loss: 0.6794
# Epoch 21/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6841 - val_loss: 0.7159
# Epoch 22/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6734 - val_loss: 0.6513
# Epoch 23/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6789 - val_loss: 0.6726
# Epoch 24/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6639 - val_loss: 0.6522
# Epoch 25/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6518 - val_loss: 0.6399
# Epoch 26/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6080 - val_loss: 0.6025
# Epoch 27/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.
200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5357 - val_loss: 0.5315
# Epoch 97/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5772 - val_loss: 0.5762
# Epoch 98/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6026 - val_loss: 0.6032
# Epoch 99/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5542 - val_loss: 0.5512
# Epoch 100/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5292 - val_loss: 0.5277
# Epoch 101/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5508 - val_loss: 0.5418
# Epoch 102/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.5418 - val_loss: 0.5376
# Epoch 103/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5615 - val_loss: 0.5570
# Epoch 104/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5748 - val_loss: 0.5715
# Epoch 105/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5501 - val_loss: 0.5481
# Epoch 106/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5678 - val_loss: 0.5667
# Epoch 107/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5536 - val_loss: 0.5521
# Epoch 108/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5657 - val_loss: 0.5631
# Epoch 109/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5712 - val_loss: 0.5697
# Epoch 110/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5855 - val_loss: 0.5838
# Epoch 111/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5010 - val_loss: 0.5004
# Epoch 112/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5149 - val_loss: 0.5133
# Epoch 113/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4940 - val_loss: 0.4933
# Epoch 114/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5289 - val_loss: 0.5282
# Epoch 115/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5106 - val_loss: 0.5093
# Epoch 116/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5591 - val_loss: 0.5569
# Epoch 117/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5214 - val_loss: 0.5179
# Epoch 118/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5142 - val_loss: 0.5127
# Epoch 119/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5272 - val_loss: 0.5269
# Epoch 120/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.5141 - val_loss: 0.5138
# Epoch 121/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5292 - val_loss: 0.5282
# Epoch 122/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5494 - val_loss: 0.5474
# Epoch 123/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5559 - val_loss: 0.5536
# Epoch 124/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5379 - val_loss: 0.5364
# Epoch 125/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5107 - val_loss: 0.5142
# Epoch 126/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5121 - val_loss: 0.5128
# Epoch 127/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.5259 - val_loss: 0.5229
# Epoch 128/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5044 - val_loss: 0.5043
# Epoch 129/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.5071 - val_loss: 0.5059
# Epoch 130/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5329 - val_loss: 0.5399
# Epoch 131/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5482 - val_loss: 0.5486
# Epoch 132/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6154 - val_loss: 0.6181
# Epoch 133/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5459 - val_loss: 0.5390
# Epoch 134/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5741 - val_loss: 0.5702
# Epoch 135/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.5222 - val_loss: 0.5198
# Epoch 136/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5046 - val_loss: 0.5016
# Epoch 137/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5430 - val_loss: 0.5412
# Epoch 138/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5171 - val_loss: 0.5152
# Epoch 139/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4902 - val_loss: 0.4888
# Epoch 140/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.5481 - val_loss: 0.5479
# Epoch 141/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5590 - val_loss: 0.5574
# Epoch 142/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5334 - val_loss: 0.5320
# Epoch 143/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4926 - val_loss: 0.4902
# Epoch 144/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5165 - val_loss: 0.5157
# Epoch 145/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5301 - val_loss: 0.5289
# Epoch 146/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.5365 - val_loss: 0.5349
# Epoch 147/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5659 - val_loss: 0.5649
# Epoch 148/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5425 - val_loss: 0.5414
# Epoch 149/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4876 - val_loss: 0.4850
# Epoch 150/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5452 - val_loss: 0.5446
# Epoch 151/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5194 - val_loss: 0.5193
# Epoch 152/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5479 - val_loss: 0.5510
# Epoch 153/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5283 - val_loss: 0.5267
# Epoch 154/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5336 - val_loss: 0.5332
# Epoch 155/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5437 - val_loss: 0.5430
# Epoch 156/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5363 - val_loss: 0.5357
# Epoch 157/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5563 - val_loss: 0.5532
# Epoch 158/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5236 - val_loss: 0.5226
# Epoch 159/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5513 - val_loss: 0.5508
# Epoch 160/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4905 - val_loss: 0.4891
# Epoch 161/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5141 - val_loss: 0.5132
# Epoch 162/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5580 - val_loss: 0.5566
# Epoch 163/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5593 - val_loss: 0.5588
# Epoch 164/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5339 - val_loss: 0.5319
# Epoch 165/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5593 - val_loss: 0.5583
# Epoch 166/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5364 - val_loss: 0.5358
# Epoch 167/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5661 - val_loss: 0.5694
# Epoch 168/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5183 - val_loss: 0.5167
# Epoch 169/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5194 - val_loss: 0.5201
# Epoch 170/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5332 - val_loss: 0.5308
# Epoch 171/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4880 - val_loss: 0.4869
# Epoch 172/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4703 - val_loss: 0.4682
# Epoch 173/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5510 - val_loss: 0.5494
# Epoch 174/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5635 - val_loss: 0.5655
# Epoch 175/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5167 - val_loss: 0.5191
# Epoch 176/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5906 - val_loss: 0.5868
# Epoch 177/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5837 - val_loss: 0.5818
# Epoch 178/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.5300 - val_loss: 0.5291
# Epoch 179/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5190 - val_loss: 0.5178
# Epoch 180/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5592 - val_loss: 0.5581
# Epoch 181/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5593 - val_loss: 0.5598
# Epoch 182/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5639 - val_loss: 0.5627
# Epoch 183/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5294 - val_loss: 0.5246
# Epoch 184/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5000 - val_loss: 0.4950
# Epoch 185/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5393 - val_loss: 0.5372
# Epoch 186/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5025 - val_loss: 0.5023
# Epoch 187/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4588 - val_loss: 0.4633
# Epoch 188/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5158 - val_loss: 0.5134
# Epoch 189/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5185 - val_loss: 0.5183
# Epoch 190/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5874 - val_loss: 0.5911
# Epoch 191/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5736 - val_loss: 0.5656
# Epoch 192/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5334 - val_loss: 0.5321
# Epoch 193/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5069 - val_loss: 0.5061
# Epoch 194/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4994 - val_loss: 0.4992
# Epoch 195/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4992 - val_loss: 0.4980
# Epoch 196/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5183 - val_loss: 0.5179
# Epoch 197/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5437 - val_loss: 0.5440
# Epoch 198/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5193 - val_loss: 0.5179
# Epoch 199/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.5009 - val_loss: 0.5002
# Epoch 200/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.4928 - val_loss: 0.4905

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

f = plt.figure(figsize=(15,10))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
fig, ax = plt.subplots()
a = dg_train.__getitem__(8)[0] 
bb = plt.imshow(a[0,10,:,:,0]  * dg_train.std.values[0] + dg_train.mean.values[0],  cmap='viridis')
fig.colorbar(bb, orientation='vertical')
plt.show()

# %%
result = model(np.expand_dims(a[0], axis=0)).numpy()

# %%
fig, ax = plt.subplots()
bb = plt.imshow((result[0,10,:,:,0] * dg_train.std.values[0] + dg_train.mean.values[0]))
fig.colorbar(bb, orientation='vertical')
plt.show()

# %%
test_data = z_train.sel(time=slice('1979-05-01T16:00:00','1979-05-02T15:00:00' ),level = slice(1),longitude=slice(6,15.75), latitude=slice(55.5,45.75))
test_data = test_data.transpose('time', 'latitude', 'longitude', 'level')
# Normalize
mean = test_data['t'].mean(('time', 'latitude', 'longitude')).compute()
std = test_data['t'].std('time').mean(('latitude', 'longitude')).compute() 
test_data = (test_data['t'] - mean) / std
test_data = np.expand_dims(test_data.values, axis=0)
test_data.shape
# Out:
# (1, 24, 40, 40, 1)

# %% [markdown]
# ## Results
#
# Original:

# %%
fig, ax = plt.subplots(4,3, figsize=(10,10))

count = 0
for i in range(4):
    for j in range(3):
        img = test_data[0,count,:,:,0] *std.values[0] + mean.values[0]
        im = ax[i, j].imshow(img,  vmin=275, vmax=280)
        count=count +1

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
plt.colorbar(im,  cax=cbar_ax)
plt.show()

# %% [markdown]
# Decompressed:

# %%
result2 = model(test_data).numpy()

fig, ax = plt.subplots(4,3, figsize=(10,10))

count = 0
for i in range(4):
    for j in range(3):
        img = result2[0,count,:,:,0] *std.values[0] + mean.values[0]
        im = ax[i, j].imshow(img,  vmin=275, vmax=280)
        count=count +1

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
plt.colorbar(im,  cax=cbar_ax)
plt.show()

# %% [markdown]
# The checkerboard dissapeared, however, the model is not learning that good anymore. We let it run for 300 epochs. But why? Maybe we should check the Tensorboard to see how the gradients are behaving.

# %% [markdown]
# Ok, just checked the kernel weights distribution and everything seems fine...

# %%
a = result2*std.values[0] + mean.values[0]
b = test_data*std.values[0] + mean.values[0]

result3 = np.absolute(a-b)

fig, ax = plt.subplots(4, 3, figsize=(10,10))
count = 0
for i in range(4):
    for j in range(3):
        img = result3[0,count,:,:,0] 
        im = ax[i, j].imshow(img, cmap = 'Greys')
        plt.colorbar(im, ax=ax[i, j])
        count = count +1

plt.show()
