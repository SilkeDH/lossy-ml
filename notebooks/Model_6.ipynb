# %% [markdown]
# ## Model 6
#
# We will now increase the CP. Instead of 2 compression blocks, we will use 3. Since we are using time blocks with length 12 and 3 layers of compression, it will give us problems by decompressing and we will not get the same output shape, therefore we are increasing the time blocks to 32. CP = (2^3)^3 / 8 = 64. The compression ratio is 8 times greater than the one before. It also has 3.4 times more parameters than the one before. The data may be insufficient.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from collections import OrderedDict
from DataLoader import DataGenerator

# %%
import tensorflow as tf
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv3D, ReLU, LeakyReLU, BatchNormalization,\
                                    Add, Flatten, Dense, Conv3DTranspose
from tensorflow.keras.models import Model


def residual_block(x: Tensor, filters: int, kernel_size = (3, 3, 3)) -> Tensor:
    y = Conv3D(kernel_size=kernel_size, strides= 1, filters=filters, padding="same")(x)
    y = ReLU()(y)
    y = Conv3D(kernel_size=kernel_size, strides=1, filters=filters, padding="same")(y)
    return y

def encoder(x: Tensor):
    kernel_size = (3, 3, 3)
    C = 4
    num_res_blocks = 2
    num_comp_lay = 3
    
    x = Conv3D(kernel_size=kernel_size, strides=1, filters=C, padding="same")(x)
    x = LeakyReLU(alpha=0.2)(x)

    first_skip_conn = x
    
    for j in range(num_res_blocks):
        skip_connection = x
        x = residual_block(x, filters=C)
        x = Add()([skip_connection, x])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C, padding="same")(x)
    x = Add()([first_skip_conn, x])
    
    C_mult = [2, 2, 1]
    
    for i in range(num_comp_lay):
        C = int(x.get_shape()[-1])
        x = Conv3D(kernel_size=kernel_size, strides= 2, filters=C, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C_mult[i]*C, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)

        
    C = int(x.get_shape()[-1])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=int(C/2), padding="same")(x)

    return x

def decoder(x: Tensor):
    kernel_size = (3, 3, 3)
    num_res_blocks = 2
    nump_comp_lay = 3
    C = int(x.get_shape()[-1])
    
    x = Conv3D(kernel_size=kernel_size, strides=1, filters=2*C,padding="same")(x)
    
    C_div = [1, 2, 2]
    
    for i in range(nump_comp_lay):
        C = int(x.get_shape()[-1])
        C_over_div = int(int(C)/C_div[i])
        x = Conv3D(kernel_size=kernel_size,strides= 1,filters=C_over_div, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv3DTranspose(C_over_div, kernel_size=kernel_size, strides=2, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)

    skip_connection = x
    
    C = 4

    for i in range(num_res_blocks):
        B_skip_connection = x
        x = residual_block(x, filters=C)
        x = Add()([B_skip_connection, x])
        
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C, padding="same")(x)
    x = Add()([skip_connection, x])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters= 1, padding="same")(x)

    return x

def Autoencoder():
    
    inputs = Input(shape=(24, 40, 40, 1))
    
    enc = encoder(inputs)
    dec = decoder(enc)
    
    model = Model(inputs, dec)

    model.compile(
        optimizer= keras.optimizers.Adam(learning_rate=0.001),
        loss=tf.keras.losses.MeanSquaredError(),
    )

    return model

# %%
model = Autoencoder() 
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 24, 40, 40,  0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 24, 40, 40, 4 112         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 24, 40, 40, 4 0           conv3d[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 24, 40, 40, 4 436         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 24, 40, 40, 4 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 24, 40, 40, 4 436         re_lu[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 24, 40, 40, 4 0           leaky_re_lu[0][0]
#                                                                  conv3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 24, 40, 40, 4 436         add[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 24, 40, 40, 4 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 24, 40, 40, 4 436         re_lu_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 24, 40, 40, 4 0           add[0][0]
#                                                                  conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 24, 40, 40, 4 436         add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 24, 40, 40, 4 0           leaky_re_lu[0][0]
#                                                                  conv3d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 12, 20, 20, 4 436         add_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 12, 20, 20, 4 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 12, 20, 20, 8 872         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 12, 20, 20, 8 0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 6, 10, 10, 8) 1736        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 6, 10, 10, 8) 0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 6, 10, 10, 16 3472        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 6, 10, 10, 16 0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 3, 5, 5, 16)  6928        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 3, 5, 5, 16)  0           conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 3, 5, 5, 16)  6928        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 3, 5, 5, 16)  0           conv3d_11[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 3, 5, 5, 8)   3464        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 3, 5, 5, 16)  3472        conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 3, 5, 5, 16)  6928        conv3d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 3, 5, 5, 16)  0           conv3d_14[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (None, 6, 10, 10, 16 6928        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 6, 10, 10, 16 0           conv3d_transpose[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 6, 10, 10, 8) 3464        leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 6, 10, 10, 8) 0           conv3d_15[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 12, 20, 20, 8 1736        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 12, 20, 20, 8 0           conv3d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 12, 20, 20, 4 868         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 12, 20, 20, 4 0           conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 24, 40, 40, 4 436         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 24, 40, 40, 4 0           conv3d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 24, 40, 40, 4 436         leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 24, 40, 40, 4 0           conv3d_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 24, 40, 40, 4 436         re_lu_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 24, 40, 40, 4 0           leaky_re_lu_12[0][0]
#                                                                  conv3d_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 24, 40, 40, 4 436         add_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 24, 40, 40, 4 0           conv3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 24, 40, 40, 4 436         re_lu_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 24, 40, 40, 4 0           add_3[0][0]
#                                                                  conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 24, 40, 40, 4 436         add_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 24, 40, 40, 4 0           leaky_re_lu_12[0][0]
#                                                                  conv3d_21[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 24, 40, 40, 1 109         add_5[0][0]
# ==================================================================================================
# Total params: 52,249
# Trainable params: 52,249
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#months = 10
#files = set('/lsdf/kit/scc/projects/abcde/1979/0'+str(i)+'/ERA5.pl.temperature.nc' for i in range(1,months))
z_train = xr.open_mfdataset('/lsdf/kit/scc/projects/abcde/1979/*/ERA5.pl.temperature.nc', combine='by_coords')

bs=10 # batch size (from paper above)
dic = OrderedDict({'t': 1})  # Choosing first pressure level from variable temperature.
chunk_time = 24

#Define train and test datasets.
dg_train = DataGenerator(z_train.sel(time=slice('1979'), longitude=slice(6,15.75), latitude=slice(55.5,45.75)), dic, chunk_time, batch_size=bs, load=True, shuffle=True)
# Out:
# Loading data into RAM

# %%
history = model.fit(dg_train, validation_data = dg_train, epochs=200)
# Out:
# Epoch 1/200
#  1/37 [..............................] - ETA: 0s - loss: 0.8006WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0119s vs `on_train_batch_end` time: 0.0310s). Check your callbacks.
# 37/37 [==============================] - 2s 57ms/step - loss: 1.0901 - val_loss: 1.0859
# Epoch 2/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.9310 - val_loss: 0.8836
# Epoch 3/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.9033 - val_loss: 0.8735
# Epoch 4/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.8498 - val_loss: 0.8274
# Epoch 5/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.8042 - val_loss: 0.7872
# Epoch 6/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.8250 - val_loss: 0.8101
# Epoch 7/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.8428 - val_loss: 0.8167
# Epoch 8/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.7629 - val_loss: 0.7302
# Epoch 9/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.7925 - val_loss: 0.7650
# Epoch 10/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.7791 - val_loss: 0.7411
# Epoch 11/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.7664 - val_loss: 0.7328
# Epoch 12/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.7143 - val_loss: 0.6974
# Epoch 13/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6650 - val_loss: 0.6331
# Epoch 14/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.7841 - val_loss: 0.7977
# Epoch 15/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6349 - val_loss: 0.6021
# Epoch 16/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.7008 - val_loss: 0.6615
# Epoch 17/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6979 - val_loss: 0.6623
# Epoch 18/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6450 - val_loss: 0.6185
# Epoch 19/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6895 - val_loss: 0.7196
# Epoch 20/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6639 - val_loss: 0.6409
# Epoch 21/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6922 - val_loss: 0.6595
# Epoch 22/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.6757 - val_loss: 0.6562
# Epoch 23/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6306 - val_loss: 0.6120
# Epoch 24/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6416 - val_loss: 0.6169
# Epoch 25/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6829 - val_loss: 0.6493
# Epoch 26/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6147 - val_loss: 0.5773
# Epoch 27/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6177 - val_loss: 0.5657
# Epoch 28/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.5733 - val_loss: 0.5387
# Epoch 29/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.5627 - val_loss: 0.5396
# Epoch 30/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6244 - val_loss: 0.6162
# Epoch 31/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.5792 - val_loss: 0.5548
# Epoch 32/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.5290 - val_loss: 0.5118
# Epoch 33/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.6699 - val_loss: 0.7122
# Epoch 34/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.5997 - val_loss: 0.5575
# Epoch 35/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.5932 - val_loss: 0.5664
# Epoch 36/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.5649 - val_loss: 0.5556
# Epoch 37/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.5292 - val_loss: 0.4958
# Epoch 38/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.5030 - val_loss: 0.4683
# Epoch 39/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.5064 - val_loss: 0.4956
# Epoch 40/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4861 - val_loss: 0.4821
# Epoch 41/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4873 - val_loss: 0.4823
# Epoch 42/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4620 - val_loss: 0.4254
# Epoch 43/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4623 - val_loss: 0.4306
# Epoch 44/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4428 - val_loss: 0.4012
# Epoch 45/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4595 - val_loss: 0.4675
# Epoch 46/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4792 - val_loss: 0.4746
# Epoch 47/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4801 - val_loss: 0.5026
# Epoch 48/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4911 - val_loss: 0.4363
# Epoch 49/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.4115 - val_loss: 0.3879
# Epoch 50/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4570 - val_loss: 0.4059
# Epoch 51/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4128 - val_loss: 0.3942
# Epoch 52/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4029 - val_loss: 0.4230
# Epoch 53/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4147 - val_loss: 0.3833
# Epoch 54/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4444 - val_loss: 0.4472
# Epoch 55/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4004 - val_loss: 0.3869
# Epoch 56/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4274 - val_loss: 0.3843
# Epoch 57/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3991 - val_loss: 0.4046
# Epoch 58/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4523 - val_loss: 0.4842
# Epoch 59/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3775 - val_loss: 0.3544
# Epoch 60/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4070 - val_loss: 0.3856
# Epoch 61/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3913 - val_loss: 0.3656
# Epoch 62/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3731 - val_loss: 0.3485
# Epoch 63/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4122 - val_loss: 0.4182
# Epoch 64/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4519 - val_loss: 0.4206
# Epoch 65/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4127 - val_loss: 0.4115
# Epoch 66/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4285 - val_loss: 0.4013
# Epoch 67/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4173 - val_loss: 0.4234
# Epoch 68/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3943 - val_loss: 0.3390
# Epoch 69/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3552 - val_loss: 0.3326
# Epoch 70/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4195 - val_loss: 0.4064
# Epoch 71/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3896 - val_loss: 0.3522
# Epoch 72/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3670 - val_loss: 0.3484
# Epoch 73/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3877 - val_loss: 0.3791
# Epoch 74/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4211 - val_loss: 0.3842
# Epoch 75/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3735 - val_loss: 0.3765
# Epoch 76/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3730 - val_loss: 0.3578
# Epoch 77/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4196 - val_loss: 0.3963
# Epoch 78/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3617 - val_loss: 0.3344
# Epoch 79/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3718 - val_loss: 0.3656
# Epoch 80/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3602 - val_loss: 0.3569
# Epoch 81/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3966 - val_loss: 0.3609
# Epoch 82/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3802 - val_loss: 0.3295
# Epoch 83/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3581 - val_loss: 0.3299
# Epoch 84/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3514 - val_loss: 0.3415
# Epoch 85/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3658 - val_loss: 0.3462
# Epoch 86/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3759 - val_loss: 0.3776
# Epoch 87/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3807 - val_loss: 0.3789
# Epoch 88/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3298 - val_loss: 0.2993
# Epoch 89/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3354 - val_loss: 0.3129
# Epoch 90/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3070 - val_loss: 0.2967
# Epoch 91/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3331 - val_loss: 0.3180
# Epoch 92/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3197 - val_loss: 0.2899
# Epoch 93/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3419 - val_loss: 0.3244
# Epoch 94/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3001 - val_loss: 0.2840
# Epoch 95/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2861 - val_loss: 0.2832
# Epoch 96/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3329 - val_loss: 0.3372
# Epoch 97/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3586 - val_loss: 0.3275
# Epoch 98/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3495 - val_loss: 0.3249
# Epoch 99/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3149 - val_loss: 0.3188
# Epoch 100/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3246 - val_loss: 0.2982
# Epoch 101/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2940 - val_loss: 0.2753
# Epoch 102/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3169 - val_loss: 0.3100
# Epoch 103/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2927 - val_loss: 0.3020
# Epoch 104/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3232 - val_loss: 0.2852
# Epoch 105/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3317 - val_loss: 0.3053
# Epoch 106/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2725 - val_loss: 0.2568
# Epoch 107/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2836 - val_loss: 0.2871
# Epoch 108/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3038 - val_loss: 0.2909
# Epoch 109/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2869 - val_loss: 0.2624
# Epoch 110/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2761 - val_loss: 0.2760
# Epoch 111/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2756 - val_loss: 0.2627
# Epoch 112/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2815 - val_loss: 0.3102
# Epoch 113/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3251 - val_loss: 0.3097
# Epoch 114/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3172 - val_loss: 0.2791
# Epoch 115/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3046 - val_loss: 0.2974
# Epoch 116/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2821 - val_loss: 0.2616
# Epoch 117/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2947 - val_loss: 0.2933
# Epoch 118/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3390 - val_loss: 0.3164
# Epoch 119/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3158 - val_loss: 0.2842
# Epoch 120/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2891 - val_loss: 0.2623
# Epoch 121/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2486 - val_loss: 0.2450
# Epoch 122/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2916 - val_loss: 0.2708
# Epoch 123/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2858 - val_loss: 0.2692
# Epoch 124/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2721 - val_loss: 0.2486
# Epoch 125/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2486 - val_loss: 0.2439
# Epoch 126/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2967 - val_loss: 0.2860
# Epoch 127/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2826 - val_loss: 0.2802
# Epoch 128/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3106 - val_loss: 0.3096
# Epoch 129/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3348 - val_loss: 0.2979
# Epoch 130/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3104 - val_loss: 0.2864
# Epoch 131/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3138 - val_loss: 0.3302
# Epoch 132/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2812 - val_loss: 0.2486
# Epoch 133/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2566 - val_loss: 0.2324
# Epoch 134/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2471 - val_loss: 0.2421
# Epoch 135/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2712 - val_loss: 0.2484
# Epoch 136/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2739 - val_loss: 0.2709
# Epoch 137/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2662 - val_loss: 0.2654
# Epoch 138/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.3116 - val_loss: 0.2818
# Epoch 139/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2591 - val_loss: 0.2446
# Epoch 140/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2782 - val_loss: 0.2605
# Epoch 141/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2685 - val_loss: 0.2444
# Epoch 142/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2563 - val_loss: 0.2548
# Epoch 143/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2838 - val_loss: 0.2765
# Epoch 144/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2557 - val_loss: 0.2484
# Epoch 145/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2745 - val_loss: 0.2584
# Epoch 146/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2563 - val_loss: 0.2452
# Epoch 147/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2487 - val_loss: 0.2311
# Epoch 148/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2478 - val_loss: 0.2490
# Epoch 149/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2382 - val_loss: 0.2376
# Epoch 150/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2742 - val_loss: 0.2591
# Epoch 151/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2705 - val_loss: 0.2561
# Epoch 152/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2669 - val_loss: 0.2642
# Epoch 153/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2874 - val_loss: 0.2782
# Epoch 154/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2793 - val_loss: 0.2458
# Epoch 155/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2560 - val_loss: 0.2355
# Epoch 156/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2472 - val_loss: 0.2229
# Epoch 157/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2489 - val_loss: 0.2309
# Epoch 158/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2346 - val_loss: 0.2242
# Epoch 159/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2572 - val_loss: 0.2518
# Epoch 160/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2450 - val_loss: 0.2235
# Epoch 161/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2526 - val_loss: 0.2483
# Epoch 162/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2444 - val_loss: 0.2299
# Epoch 163/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2276 - val_loss: 0.2154
# Epoch 164/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2651 - val_loss: 0.2560
# Epoch 165/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2540 - val_loss: 0.2325
# Epoch 166/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2490 - val_loss: 0.2272
# Epoch 167/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2363 - val_loss: 0.2153
# Epoch 168/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2522 - val_loss: 0.2369
# Epoch 169/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2337 - val_loss: 0.2124
# Epoch 170/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2577 - val_loss: 0.2403
# Epoch 171/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2418 - val_loss: 0.2461
# Epoch 172/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2548 - val_loss: 0.2262
# Epoch 173/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2367 - val_loss: 0.2354
# Epoch 174/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2250 - val_loss: 0.2045
# Epoch 175/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2379 - val_loss: 0.2276
# Epoch 176/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2626 - val_loss: 0.2338
# Epoch 177/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2390 - val_loss: 0.2237
# Epoch 178/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2290 - val_loss: 0.2156
# Epoch 179/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2448 - val_loss: 0.2460
# Epoch 180/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2257 - val_loss: 0.2219
# Epoch 181/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2492 - val_loss: 0.2268
# Epoch 182/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2259 - val_loss: 0.2321
# Epoch 183/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2149 - val_loss: 0.2008
# Epoch 184/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2096 - val_loss: 0.2012
# Epoch 185/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2478 - val_loss: 0.2563
# Epoch 186/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2213 - val_loss: 0.2109
# Epoch 187/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2364 - val_loss: 0.2363
# Epoch 188/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2254 - val_loss: 0.2120
# Epoch 189/200
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2382 - val_loss: 0.2321
# Epoch 190/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2433 - val_loss: 0.2183
# Epoch 191/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2373 - val_loss: 0.2236
# Epoch 192/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.1984 - val_loss: 0.1910
# Epoch 193/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2186 - val_loss: 0.2021
# Epoch 194/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2597 - val_loss: 0.2508
# Epoch 195/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2513 - val_loss: 0.2282
# Epoch 196/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2354 - val_loss: 0.2117
# Epoch 197/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2229 - val_loss: 0.2151
# Epoch 198/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2279 - val_loss: 0.2457
# Epoch 199/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2428 - val_loss: 0.2239
# Epoch 200/200
# 37/37 [==============================] - 2s 52ms/step - loss: 0.2378 - val_loss: 0.2095

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

f = plt.figure(figsize=(15,10))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
fig, ax = plt.subplots()
a = dg_train.__getitem__(8)[0] 
bb = plt.imshow(a[0,10,:,:,0]  * dg_train.std.values[0] + dg_train.mean.values[0],  cmap='viridis')
fig.colorbar(bb, orientation='vertical')
plt.show()

# %%
result = model(np.expand_dims(a[0], axis=0)).numpy()
result.shape
# Out:
# (1, 24, 40, 40, 1)

# %%
fig, ax = plt.subplots()
bb = plt.imshow((result[0,10,:,:,0] * dg_train.std.values[0] + dg_train.mean.values[0]))
fig.colorbar(bb, orientation='vertical')
plt.show()

# %%
test_data = z_train.sel(time=slice('1979-05-01T16:00:00','1979-05-02T15:00:00' ),level = slice(1),longitude=slice(6,15.75), latitude=slice(55.5,45.75))
test_data = test_data.transpose('time', 'latitude', 'longitude', 'level')
# Normalize
mean = test_data['t'].mean(('time', 'latitude', 'longitude')).compute()
std = test_data['t'].std('time').mean(('latitude', 'longitude')).compute() 
test_data = (test_data['t'] - mean) / std
test_data = np.expand_dims(test_data.values, axis=0)
test_data.shape
# Out:
# (1, 24, 40, 40, 1)

# %% [markdown]
# ## Results
#
# Original:

# %%
fig, ax = plt.subplots(4,3, figsize=(10,10))

count = 0
for i in range(4):
    for j in range(3):
        img = test_data[0,count,:,:,0] *std.values[0] + mean.values[0]
        im = ax[i, j].imshow(img,  vmin=275, vmax=280)
        count=count +1

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
plt.colorbar(im,  cax=cbar_ax)
plt.show()

# %% [markdown]
# Decompressed:

# %%
result2 = model(test_data).numpy()

fig, ax = plt.subplots(4,3, figsize=(10,10))

count = 0
for i in range(4):
    for j in range(3):
        img = result2[0,count,:,:,0] *std.values[0] + mean.values[0]
        im = ax[i, j].imshow(img,  vmin=275, vmax=280)
        count=count +1

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
plt.colorbar(im,  cax=cbar_ax)
plt.show()

# %% [markdown]
# The network is not learning anymore. The results are not good. We only have like 8k data points and 52k parameter, no wonder we are not getting something good.

# %%
a = result2*std.values[0] + mean.values[0]
b = test_data*std.values[0] + mean.values[0]

result3 = np.absolute(a-b)

fig, ax = plt.subplots(4, 3, figsize=(10,10))
count = 0
for i in range(4):
    for j in range(3):
        img = result3[0,count,:,:,0] 
        im = ax[i, j].imshow(img, cmap = 'Greys')
        plt.colorbar(im, ax=ax[i, j])
        count = count +1

plt.show()
