# %% [markdown]
# ## Model 5.2
#
# We will now try to increase the CP.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from collections import OrderedDict
from DataLoader import DataGenerator

# %%
import tensorflow as tf
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv3D, ReLU, LeakyReLU, BatchNormalization,\
                                    Add, Flatten, Dense, Conv3DTranspose
from tensorflow.keras.models import Model


def residual_block(x: Tensor, filters: int, kernel_size = (3, 3, 3)) -> Tensor:
    y = Conv3D(kernel_size=kernel_size, strides= 1, filters=filters, padding="same")(x)
    y = ReLU()(y)
    y = Conv3D(kernel_size=kernel_size, strides=1, filters=filters, padding="same")(y)
    return y

def encoder(x: Tensor):
    kernel_size = (3, 3, 3)
    C = 4
    num_res_blocks = 2
    num_comp_lay = 2
    
    x = Conv3D(kernel_size=kernel_size, strides=1, filters=C, padding="same")(x)
    x = LeakyReLU(alpha=0.2)(x)

    first_skip_conn = x
    
    for j in range(num_res_blocks):
        skip_connection = x
        x = residual_block(x, filters=C)
        x = Add()([skip_connection, x])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C, padding="same")(x)
    x = Add()([first_skip_conn, x])
    
    C_mult = [2, 1]
    
    for i in range(num_comp_lay):
        C = int(x.get_shape()[-1])
        x = Conv3D(kernel_size=kernel_size, strides= 2, filters=C, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C_mult[i]*C, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)

        
    C = int(x.get_shape()[-1])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=int(C/2), padding="same")(x)

    return x

def decoder(x: Tensor):
    kernel_size = (3, 3, 3)
    num_res_blocks = 2
    nump_comp_lay = 2
    C = int(x.get_shape()[-1])
    
    x = Conv3D(kernel_size=kernel_size, strides=1, filters=2*C,padding="same")(x)
    
    C_div = [1, 2]
    
    for i in range(nump_comp_lay):
        C = int(x.get_shape()[-1])
        C_over_div = int(int(C)/C_div[i])
        x = Conv3D(kernel_size=kernel_size,strides= 1,filters=C_over_div, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv3DTranspose(C_over_div, kernel_size=kernel_size, strides=2, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)

    skip_connection = x
    
    C = 4

    for i in range(num_res_blocks):
        B_skip_connection = x
        x = residual_block(x, filters=C)
        x = Add()([B_skip_connection, x])
        
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C, padding="same")(x)
    x = Add()([skip_connection, x])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters= 1, padding="same")(x)

    return x

def Autoencoder():
    
    inputs = Input(shape=(12, 40, 40, 1))
    
    enc = encoder(inputs)
    dec = decoder(enc)
    
    model = Model(inputs, dec)

    model.compile(
        optimizer= keras.optimizers.Adam(learning_rate=0.001),
        loss=tf.keras.losses.MeanSquaredError(),
    )

    return model

# %%
model = Autoencoder() 
#model.summary()

# %%
#months = 10
#files = set('/lsdf/kit/scc/projects/abcde/1979/0'+str(i)+'/ERA5.pl.temperature.nc' for i in range(1,months))
z_train = xr.open_mfdataset('/lsdf/kit/scc/projects/abcde/1979/*/ERA5.pl.temperature.nc',  combine='by_coords')

bs=10 # batch size (from paper above)
dic = OrderedDict({'t': 1000})  # Choosing first pressure level from variable temperature.
chunk_time = 12

#Define train and test datasets.
dg_train = DataGenerator(z_train.sel(time=slice('1979'), longitude=slice(6,15.75), latitude=slice(55.5,45.75)), dic, chunk_time, batch_size=bs, load=True, shuffle=True)
# Out:
# Loading data into RAM

# %%
history = model.fit(dg_train, validation_data = dg_train, epochs=200)
# Out:
# Epoch 1/200
#  1/73 [..............................] - ETA: 0s - loss: 0.7286WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0083s vs `on_train_batch_end` time: 0.0196s). Check your callbacks.
# 73/73 [==============================] - 2s 32ms/step - loss: 0.9726 - val_loss: 0.8238
# Epoch 2/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.7170 - val_loss: 0.7143
# Epoch 3/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.7098 - val_loss: 0.6910
# Epoch 4/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.6229 - val_loss: 0.6044
# Epoch 5/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.5905 - val_loss: 0.5094
# Epoch 6/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.5003 - val_loss: 0.4844
# Epoch 7/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.5258 - val_loss: 0.5252
# Epoch 8/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.4693 - val_loss: 0.4188
# Epoch 9/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.4010 - val_loss: 0.3557
# Epoch 10/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.3315 - val_loss: 0.2907
# Epoch 11/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.2647 - val_loss: 0.2283
# Epoch 12/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.2378 - val_loss: 0.2383
# Epoch 13/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.2061 - val_loss: 0.1887
# Epoch 14/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.2017 - val_loss: 0.2038
# Epoch 15/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1892 - val_loss: 0.1813
# Epoch 16/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1809 - val_loss: 0.1692
# Epoch 17/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1662 - val_loss: 0.1594
# Epoch 18/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1741 - val_loss: 0.1625
# Epoch 19/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1591 - val_loss: 0.1531
# Epoch 20/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1630 - val_loss: 0.1612
# Epoch 21/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1530 - val_loss: 0.1540
# Epoch 22/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1559 - val_loss: 0.1575
# Epoch 23/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1532 - val_loss: 0.1667
# Epoch 24/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1546 - val_loss: 0.1535
# Epoch 25/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1545 - val_loss: 0.1523
# Epoch 26/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1538 - val_loss: 0.1434
# Epoch 27/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1422 - val_loss: 0.1443
# Epoch 28/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1338 - val_loss: 0.1380
# Epoch 29/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1418 - val_loss: 0.1388
# Epoch 30/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1383 - val_loss: 0.1312
# Epoch 31/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1308 - val_loss: 0.1258
# Epoch 32/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1225 - val_loss: 0.1278
# Epoch 33/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1403 - val_loss: 0.1504
# Epoch 34/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1587 - val_loss: 0.1409
# Epoch 35/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1376 - val_loss: 0.1207
# Epoch 36/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1287 - val_loss: 0.1322
# Epoch 37/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1198 - val_loss: 0.1153
# Epoch 38/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1284 - val_loss: 0.1220
# Epoch 39/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1258 - val_loss: 0.1182
# Epoch 40/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1150 - val_loss: 0.1025
# Epoch 41/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1110 - val_loss: 0.1205
# Epoch 42/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1058 - val_loss: 0.0973
# Epoch 43/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1174 - val_loss: 0.1086
# Epoch 44/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1053 - val_loss: 0.1091
# Epoch 45/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1078 - val_loss: 0.1031
# Epoch 46/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1030 - val_loss: 0.1031
# Epoch 47/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0972 - val_loss: 0.0903
# Epoch 48/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.1022 - val_loss: 0.0935
# Epoch 49/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0948 - val_loss: 0.0860
# Epoch 50/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0876 - val_loss: 0.0883
# Epoch 51/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0821 - val_loss: 0.0763
# Epoch 52/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0924 - val_loss: 0.0912
# Epoch 53/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0925 - val_loss: 0.0835
# Epoch 54/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0823 - val_loss: 0.0831
# Epoch 55/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0883 - val_loss: 0.0799
# Epoch 56/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0849 - val_loss: 0.0761
# Epoch 57/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0766 - val_loss: 0.0696
# Epoch 58/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0741 - val_loss: 0.0713
# Epoch 59/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0704 - val_loss: 0.0719
# Epoch 60/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0682 - val_loss: 0.0649
# Epoch 61/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0711 - val_loss: 0.0824
# Epoch 62/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0836 - val_loss: 0.0750
# Epoch 63/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0712 - val_loss: 0.0657
# Epoch 64/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0748 - val_loss: 0.0832
# Epoch 65/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0731 - val_loss: 0.0703
# Epoch 66/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0783 - val_loss: 0.0797
# Epoch 67/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0795 - val_loss: 0.0761
# Epoch 68/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0682 - val_loss: 0.0693
# Epoch 69/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0702 - val_loss: 0.0634
# Epoch 70/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0585 - val_loss: 0.0538
# Epoch 71/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0600 - val_loss: 0.0528
# Epoch 72/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0582 - val_loss: 0.0511
# Epoch 73/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0543 - val_loss: 0.0604
# Epoch 74/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0546 - val_loss: 0.0488
# Epoch 75/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0460 - val_loss: 0.0416
# Epoch 76/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0560 - val_loss: 0.0497
# Epoch 77/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0446 - val_loss: 0.0439
# Epoch 78/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0385 - val_loss: 0.0392
# Epoch 79/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0377 - val_loss: 0.0344
# Epoch 80/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0384 - val_loss: 0.0446
# Epoch 81/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0387 - val_loss: 0.0340
# Epoch 82/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0380 - val_loss: 0.0347
# Epoch 83/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0368 - val_loss: 0.0457
# Epoch 84/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0388 - val_loss: 0.0335
# Epoch 85/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0316 - val_loss: 0.0296
# Epoch 86/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0352 - val_loss: 0.0306
# Epoch 87/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0295 - val_loss: 0.0279
# Epoch 88/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0304 - val_loss: 0.0342
# Epoch 89/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0301 - val_loss: 0.0280
# Epoch 90/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0311 - val_loss: 0.0399
# Epoch 91/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0313 - val_loss: 0.0278
# Epoch 92/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0344 - val_loss: 0.0323
# Epoch 93/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0313 - val_loss: 0.0363
# Epoch 94/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0288 - val_loss: 0.0237
# Epoch 95/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0301 - val_loss: 0.0268
# Epoch 96/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0275 - val_loss: 0.0292
# Epoch 97/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0332 - val_loss: 0.0283
# Epoch 98/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0262 - val_loss: 0.0255
# Epoch 99/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0323 - val_loss: 0.0870
# Epoch 100/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0454 - val_loss: 0.0292
# Epoch 101/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0331 - val_loss: 0.0304
# Epoch 102/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0263 - val_loss: 0.0232
# Epoch 103/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0219 - val_loss: 0.0226
# Epoch 104/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0234 - val_loss: 0.0223
# Epoch 105/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0265 - val_loss: 0.0254
# Epoch 106/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0266 - val_loss: 0.0237
# Epoch 107/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0228 - val_loss: 0.0220
# Epoch 108/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0294 - val_loss: 0.0240
# Epoch 109/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0208 - val_loss: 0.0197
# Epoch 110/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0218 - val_loss: 0.0238
# Epoch 111/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0279 - val_loss: 0.0282
# Epoch 112/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0248 - val_loss: 0.0231
# Epoch 113/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0249 - val_loss: 0.0256
# Epoch 114/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0241 - val_loss: 0.0202
# Epoch 115/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0214 - val_loss: 0.0204
# Epoch 116/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0220 - val_loss: 0.0193
# Epoch 117/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0213 - val_loss: 0.0239
# Epoch 118/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0210 - val_loss: 0.0195
# Epoch 119/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0237 - val_loss: 0.0210
# Epoch 120/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0232 - val_loss: 0.0226
# Epoch 121/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0221 - val_loss: 0.0211
# Epoch 122/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0262 - val_loss: 0.0403
# Epoch 123/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0343 - val_loss: 0.0351
# Epoch 124/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0226 - val_loss: 0.0200
# Epoch 125/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0219 - val_loss: 0.0321
# Epoch 126/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0360 - val_loss: 0.0266
# Epoch 127/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0216 - val_loss: 0.0183
# Epoch 128/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0188 - val_loss: 0.0181
# Epoch 129/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0179 - val_loss: 0.0200
# Epoch 130/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0287 - val_loss: 0.0250
# Epoch 131/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0237 - val_loss: 0.0192
# Epoch 132/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0196 - val_loss: 0.0177
# Epoch 133/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0201 - val_loss: 0.0255
# Epoch 134/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0204 - val_loss: 0.0208
# Epoch 135/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0188 - val_loss: 0.0164
# Epoch 136/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0194 - val_loss: 0.0190
# Epoch 137/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0417 - val_loss: 0.0373
# Epoch 138/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0266 - val_loss: 0.0179
# Epoch 139/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0194 - val_loss: 0.0185
# Epoch 140/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0200 - val_loss: 0.0172
# Epoch 141/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0181 - val_loss: 0.0173
# Epoch 142/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0157 - val_loss: 0.0150
# Epoch 143/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0167 - val_loss: 0.0160
# Epoch 144/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0198 - val_loss: 0.0199
# Epoch 145/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0510 - val_loss: 0.0404
# Epoch 146/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0264 - val_loss: 0.0198
# Epoch 147/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0177 - val_loss: 0.0160
# Epoch 148/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0216 - val_loss: 0.0272
# Epoch 149/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0190 - val_loss: 0.0167
# Epoch 150/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0165 - val_loss: 0.0177
# Epoch 151/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0176 - val_loss: 0.0158
# Epoch 152/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0165 - val_loss: 0.0145
# Epoch 153/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0165 - val_loss: 0.0147
# Epoch 154/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0155 - val_loss: 0.0167
# Epoch 155/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0212 - val_loss: 0.0194
# Epoch 156/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0194 - val_loss: 0.0199
# Epoch 157/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0189 - val_loss: 0.0162
# Epoch 158/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0196 - val_loss: 0.0257
# Epoch 159/200
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0248 - val_loss: 0.0248
# Epoch 160/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0168 - val_loss: 0.0159
# Epoch 161/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0161 - val_loss: 0.0145
# Epoch 162/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0206 - val_loss: 0.0193
# Epoch 163/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0180 - val_loss: 0.0164
# Epoch 164/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0173 - val_loss: 0.0181
# Epoch 165/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0166 - val_loss: 0.0262
# Epoch 166/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0171 - val_loss: 0.0152
# Epoch 167/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0137 - val_loss: 0.0133
# Epoch 168/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0172 - val_loss: 0.0208
# Epoch 169/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0276 - val_loss: 0.0208
# Epoch 170/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0171 - val_loss: 0.0153
# Epoch 171/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0162 - val_loss: 0.0183
# Epoch 172/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0184 - val_loss: 0.0234
# Epoch 173/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0167 - val_loss: 0.0151
# Epoch 174/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0213 - val_loss: 0.0323
# Epoch 175/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0242 - val_loss: 0.0186
# Epoch 176/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0167 - val_loss: 0.0158
# Epoch 177/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0173 - val_loss: 0.0159
# Epoch 178/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0159 - val_loss: 0.0191
# Epoch 179/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0148 - val_loss: 0.0135
# Epoch 180/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0158 - val_loss: 0.0157
# Epoch 181/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0166 - val_loss: 0.0238
# Epoch 182/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0183 - val_loss: 0.0165
# Epoch 183/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0151 - val_loss: 0.0144
# Epoch 184/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0193 - val_loss: 0.0164
# Epoch 185/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0151 - val_loss: 0.0127
# Epoch 186/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0141 - val_loss: 0.0135
# Epoch 187/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0172 - val_loss: 0.0158
# Epoch 188/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0185 - val_loss: 0.0250
# Epoch 189/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0198 - val_loss: 0.0286
# Epoch 190/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0198 - val_loss: 0.0147
# Epoch 191/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0138 - val_loss: 0.0120
# Epoch 192/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 193/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 194/200
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0180 - val_loss: 0.0166
# Epoch 195/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0209 - val_loss: 0.0209
# Epoch 196/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0229 - val_loss: 0.0150
# Epoch 197/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0145 - val_loss: 0.0148
# Epoch 198/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 199/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0150 - val_loss: 0.0127
# Epoch 200/200
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0133 - val_loss: 0.0149

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

f = plt.figure(figsize=(15,10))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
fig, ax = plt.subplots()
a = dg_train.__getitem__(8)[0] 
bb = plt.imshow(a[0,10,:,:,0]  * dg_train.std.values[0] + dg_train.mean.values[0],  cmap='viridis')
fig.colorbar(bb, orientation='vertical')
plt.show()

# %%
result = model(np.expand_dims(a[0], axis=0)).numpy()
result.shape
# Out:
# (1, 12, 40, 40, 1)

# %%
fig, ax = plt.subplots()
bb = plt.imshow((result[0,10,:,:,0] * dg_train.std.values[0] + dg_train.mean.values[0]))
fig.colorbar(bb, orientation='vertical')
plt.show()

# %%
test_data = z_train.sel(time=slice('1979-02-01T10:00:00','1979-02-01T21:00:00' ),level = slice(990,1000),longitude=slice(6,15.75), latitude=slice(55.5,45.75))
test_data = test_data.transpose('time', 'latitude', 'longitude', 'level')
# Normalize
mean = test_data['t'].mean(('time', 'latitude', 'longitude')).compute()
std = test_data['t'].std('time').mean(('latitude', 'longitude')).compute() 
test_data = (test_data['t'] - mean) / std
test_data = np.expand_dims(test_data.values, axis=0)
test_data.shape
# Out:
# (1, 12, 40, 40, 1)

# %% [markdown]
# ## Results
#
# Original:

# %%
fig, ax = plt.subplots(4,3, figsize=(10,10))

count = 0
for i in range(4):
    for j in range(3):
        img = test_data[0,count,:,:,0] *std.values[0] + mean.values[0]
        im = ax[i, j].imshow(img,  vmin=273, vmax=282)
        count=count +1

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
plt.colorbar(im,  cax=cbar_ax)
plt.show()

# %% [markdown]
# Decompressed:

# %%
result2 = model(test_data).numpy()

fig, ax = plt.subplots(4,3, figsize=(10,10))

count = 0
for i in range(4):
    for j in range(3):
        img = result2[0,count,:,:,0] *std.values[0] + mean.values[0]
        im = ax[i, j].imshow(img,  vmin=273, vmax=282)
        count=count +1

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
plt.colorbar(im,  cax=cbar_ax)
plt.show()

# %% [markdown]
# a = result2*std.values[0] + mean.values[0]
# b = test_data*std.values[0] + mean.values[0]
#
# result3 = np.absolute(a-b)
#
# fig, ax = plt.subplots(4, 3, figsize=(10,10))
#
# for i in range(4):
#     for j in range(3):
#         img = result3[0,i,:,:,0]
#         im = ax[i, j].imshow(img, cmap = 'Greys')
#         plt.colorbar(im, ax=ax[i, j])
#
# plt.show()The results are good!

# %%
a = result2*std.values[0] + mean.values[0]
b = test_data*std.values[0] + mean.values[0]

result3 = np.absolute(a-b)

fig, ax = plt.subplots(4, 3, figsize=(10,10))
count = 0
for i in range(4):
    for j in range(3):
        img = result3[0,count,:,:,0] 
        im = ax[i, j].imshow(img, cmap = 'Greys')
        plt.colorbar(im, ax=ax[i, j])
        count = count +1

plt.show()
