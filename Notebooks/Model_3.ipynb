# %% [markdown]
# ## Model 3
#
# This model focuses on the checkerboard effect in model 2. It is also discussed in: https://distill.pub/2016/deconv-checkerboard/. The CP is the same one but we are using filter size of (3,3,3) instead of (4,4,4). Since we are using a stride of 2 and 3 is not a multiple of 2, we are expecting a stronger checkerboard effect. However, maybe its not the size of stride/filter the problem, but the number of parameters that our model has, model 2 has twice as much as model 3.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from collections import OrderedDict
from DataLoader import DataGenerator

# %%
model = models.Sequential()
model.add(layers.Conv3D(5, (3, 3, 3), activation='relu', strides=2, input_shape=(12, 40, 40, 1), padding="same", data_format = "channels_last"))
model.add(layers.Conv3D(10, (3, 3, 3), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(5, (3, 3, 3), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(1, (3, 3, 3), strides=2, padding="same", activation = None))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 6, 20, 20, 5)      140
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 3, 10, 10, 10)     1360
# _________________________________________________________________
# conv3d_transpose (Conv3DTran (None, 6, 20, 20, 5)      1355
# _________________________________________________________________
# conv3d_transpose_1 (Conv3DTr (None, 12, 40, 40, 1)     136
# =================================================================
# Total params: 2,991
# Trainable params: 2,991
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.MeanSquaredError())

# %%
months = 10
files = set('/lsdf/kit/scc/projects/abcde/1979/0'+str(i)+'/ERA5.pl.temperature.nc' for i in range(1,months))
z_train = xr.open_mfdataset(files, combine='by_coords')

bs=10 # batch size (from paper above)
dic = OrderedDict({'t': 1})  # Choosing first pressure level from variable temperature.
chunk_time = 12

#Define train and test datasets.
dg_train = DataGenerator(z_train.sel(time=slice('1979'), longitude=slice(6,15.75), latitude=slice(55.5,45.75)), dic, chunk_time, batch_size=bs, load=True, shuffle=True)
# Out:
# Loading data into RAM

# %%
history = model.fit(dg_train, validation_data = dg_train, epochs=100)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 1s 9ms/step - loss: 0.9496 - val_loss: 0.8354
# Epoch 2/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.7385 - val_loss: 0.5966
# Epoch 3/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.4140 - val_loss: 0.2598
# Epoch 4/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.2023 - val_loss: 0.1559
# Epoch 5/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.1394 - val_loss: 0.1183
# Epoch 6/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.1084 - val_loss: 0.0967
# Epoch 7/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0893 - val_loss: 0.0817
# Epoch 8/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0707 - val_loss: 0.0655
# Epoch 9/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0636 - val_loss: 0.0568
# Epoch 10/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0580 - val_loss: 0.0512
# Epoch 11/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0512 - val_loss: 0.0471
# Epoch 12/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0385 - val_loss: 0.0348
# Epoch 13/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0356 - val_loss: 0.0319
# Epoch 14/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0292 - val_loss: 0.0264
# Epoch 15/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0256 - val_loss: 0.0234
# Epoch 16/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0229 - val_loss: 0.0211
# Epoch 17/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0187 - val_loss: 0.0176
# Epoch 18/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0178 - val_loss: 0.0163
# Epoch 19/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0158 - val_loss: 0.0149
# Epoch 20/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0142 - val_loss: 0.0140
# Epoch 21/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0115 - val_loss: 0.0106
# Epoch 22/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0112 - val_loss: 0.0108
# Epoch 23/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0099 - val_loss: 0.0095
# Epoch 24/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0101 - val_loss: 0.0097
# Epoch 25/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0080 - val_loss: 0.0077
# Epoch 26/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 27/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 28/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 29/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 30/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 31/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 32/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 33/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 34/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 35/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 36/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 37/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 38/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 39/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 40/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 41/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 42/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 43/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0069
# Epoch 44/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 45/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 46/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 47/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0055
# Epoch 48/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 49/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 50/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 51/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 52/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 53/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 54/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 55/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 56/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 57/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 58/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 59/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 60/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 61/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 62/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 63/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 64/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 65/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 66/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 67/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 68/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0049
# Epoch 69/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 70/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 71/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 72/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 73/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 74/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 75/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0039
# Epoch 76/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 77/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 78/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 79/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 80/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 81/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 82/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 83/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 84/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 85/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 86/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 87/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0047
# Epoch 88/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 89/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0152
# Epoch 90/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 91/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 92/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 93/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 94/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 95/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 96/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 97/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 98/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 99/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 100/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0034

# %%
a = dg_train.__getitem__(8)[0]
plt.imshow(a[0,11,:,:,0])
plt.show()

# %%
result = model(np.expand_dims(a[0], axis=0)).numpy()

# %%
plt.imshow((result[0,11,:,:,0]))
plt.show()

# %%
test_data = z_train.sel(time=slice('1979-05-01T16:00:00','1979-05-02T03:00:00' ),level = slice(1),longitude=slice(6,15.75), latitude=slice(55.5,45.75))
test_data = test_data.transpose('time', 'latitude', 'longitude', 'level')
# Normalize
mean = test_data['t'].mean(('time', 'latitude', 'longitude')).compute()
std = test_data['t'].std('time').mean(('latitude', 'longitude')).compute() 
test_data = (test_data['t'] - mean) / std
test_data = np.expand_dims(test_data.values, axis=0)
test_data.shape
# Out:
# (1, 12, 40, 40, 1)

# %% [markdown]
# ## Results
#
# Original:

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = test_data[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# Decompressed:

# %%
result2 = model(test_data).numpy()
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = result2[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# Indeed, we got a stronger checkerboard effect.
