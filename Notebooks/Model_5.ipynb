# %% [markdown]
# ## Model 5
#
# This model will now use skip connections to see if the learning improves. We already have 8 layers, some degradation problem may be affecting. This one will have 2 residual blocks and 2 compression blocks.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from collections import OrderedDict
from DataLoader import DataGenerator

# %%
import tensorflow as tf
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv3D, ReLU, LeakyReLU, BatchNormalization,\
                                    Add, Flatten, Dense, Conv3DTranspose
from tensorflow.keras.models import Model


def residual_block(x: Tensor, filters: int, kernel_size = (3, 3, 3)) -> Tensor:
    y = Conv3D(kernel_size=kernel_size, strides= 1, filters=filters, padding="same")(x)
    y = ReLU()(x)
    y = Conv3D(kernel_size=kernel_size, strides=1, filters=filters, padding="same")(y)
    return y

def encoder(x: Tensor):
    kernel_size = (3, 3, 3)
    C = 4
    num_res_blocks = 2
    num_comp_lay = 2
    
    x = Conv3D(kernel_size=kernel_size, strides=1, filters=C, padding="same")(x)
    x = LeakyReLU(alpha=0.2)(x)

    first_skip_conn = x
    
    for j in range(num_res_blocks):
        skip_connection = x
        x = residual_block(x, filters=C)
        x = Add()([skip_connection, x])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C, padding="same")(x)
    x = Add()([first_skip_conn, x])
    
    C_mult = [2, 1]
    
    for i in range(num_comp_lay):
        C = int(x.get_shape()[-1])
        x = Conv3D(kernel_size=kernel_size, strides= 2, filters=C, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C_mult[i]*C, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)

        
    C = int(x.get_shape()[-1])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=int(C/2), padding="same")(x)

    return x

def decoder(x: Tensor):
    kernel_size = (3, 3, 3)
    num_res_blocks = 2
    nump_comp_lay = 2
    C = int(x.get_shape()[-1])
    
    x = Conv3D(kernel_size=kernel_size, strides=1, filters=2*C,padding="same")(x)
    
    C_div = [1, 2]
    
    for i in range(nump_comp_lay):
        C = int(x.get_shape()[-1])
        C_over_div = int(int(C)/C_div[i])
        x = Conv3D(kernel_size=kernel_size,strides= 1,filters=C_over_div, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv3DTranspose(C_over_div, kernel_size=kernel_size, strides=2, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)

    skip_connection = x
    
    C = 4

    for i in range(num_res_blocks):
        B_skip_connection = x
        x = residual_block(x, filters=C)
        x = Add()([B_skip_connection, x])
        
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C, padding="same")(x)
    x = Add()([skip_connection, x])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters= 1, padding="same")(x)

    return x

def Autoencoder():
    
    inputs = Input(shape=(12, 40, 40, 1))
    
    enc = encoder(inputs)
    dec = decoder(enc)
    
    model = Model(inputs, dec)

    model.compile(
        optimizer= keras.optimizers.Adam(learning_rate=0.001),
        loss=tf.keras.losses.MeanSquaredError(),
    )

    return model

# %%
model = Autoencoder() 
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 12, 40, 40,  0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 12, 40, 40, 4 112         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 12, 40, 40, 4 0           conv3d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 12, 40, 40, 4 0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 12, 40, 40, 4 436         re_lu[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 12, 40, 40, 4 0           leaky_re_lu[0][0]
#                                                                  conv3d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 12, 40, 40, 4 0           add[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 12, 40, 40, 4 436         re_lu_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 12, 40, 40, 4 0           add[0][0]
#                                                                  conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 12, 40, 40, 4 436         add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 12, 40, 40, 4 0           leaky_re_lu[0][0]
#                                                                  conv3d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 6, 20, 20, 4) 436         add_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 6, 20, 20, 4) 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 6, 20, 20, 8) 872         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 6, 20, 20, 8) 0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 3, 10, 10, 8) 1736        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 3, 10, 10, 8) 0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 3, 10, 10, 8) 1736        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 3, 10, 10, 8) 0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 3, 10, 10, 4) 868         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 3, 10, 10, 8) 872         conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 3, 10, 10, 8) 1736        conv3d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 3, 10, 10, 8) 0           conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (None, 6, 20, 20, 8) 1736        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 6, 20, 20, 8) 0           conv3d_transpose[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 6, 20, 20, 4) 868         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 6, 20, 20, 4) 0           conv3d_13[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 12, 40, 40, 4 436         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 12, 40, 40, 4 0           conv3d_transpose_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 12, 40, 40, 4 0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 12, 40, 40, 4 436         re_lu_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 12, 40, 40, 4 0           leaky_re_lu_8[0][0]
#                                                                  conv3d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 12, 40, 40, 4 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 12, 40, 40, 4 436         re_lu_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 12, 40, 40, 4 0           add_3[0][0]
#                                                                  conv3d_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 12, 40, 40, 4 436         add_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 12, 40, 40, 4 0           leaky_re_lu_8[0][0]
#                                                                  conv3d_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 12, 40, 40, 1 109         add_5[0][0]
# ==================================================================================================
# Total params: 14,133
# Trainable params: 14,133
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#months = 10
#files = set('/lsdf/kit/scc/projects/abcde/1979/0'+str(i)+'/ERA5.pl.temperature.nc' for i in range(1,months))
z_train = xr.open_mfdataset('/lsdf/kit/scc/projects/abcde/1979/*/ERA5.pl.temperature.nc', combine='by_coords')

bs=10 # batch size (from paper above)
dic = OrderedDict({'t': 1})  # Choosing first pressure level from variable temperature.
chunk_time = 12

#Define train and test datasets.
dg_train = DataGenerator(z_train.sel(time=slice('1979'), longitude=slice(6,15.75), latitude=slice(55.5,45.75)), dic, chunk_time, batch_size=bs, load=True, shuffle=True)
# Out:
# Loading data into RAM

# %%
history = model.fit(dg_train, validation_data = dg_train, epochs=200)
# Out:
# Epoch 1/200
#  1/73 [..............................] - ETA: 0s - loss: 1.3906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_train_batch_end` time: 0.0137s). Check your callbacks.
# 73/73 [==============================] - 2s 25ms/step - loss: 0.9499 - val_loss: 0.8535
# Epoch 2/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.7323 - val_loss: 0.6575
# Epoch 3/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.6629 - val_loss: 0.6082
# Epoch 4/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.5640 - val_loss: 0.5247
# Epoch 5/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.5333 - val_loss: 0.4979
# Epoch 6/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.5083 - val_loss: 0.4729
# Epoch 7/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.5200 - val_loss: 0.5168
# Epoch 8/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4893 - val_loss: 0.4571
# Epoch 9/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4673 - val_loss: 0.4454
# Epoch 10/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.4662 - val_loss: 0.4405
# Epoch 11/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4255 - val_loss: 0.4162
# Epoch 12/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4008 - val_loss: 0.3844
# Epoch 13/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4279 - val_loss: 0.4297
# Epoch 14/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4200 - val_loss: 0.4005
# Epoch 15/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4024 - val_loss: 0.3942
# Epoch 16/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3862 - val_loss: 0.3879
# Epoch 17/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4159 - val_loss: 0.4903
# Epoch 18/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4326 - val_loss: 0.3834
# Epoch 19/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4102 - val_loss: 0.4426
# Epoch 20/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.4000 - val_loss: 0.3828
# Epoch 21/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3853 - val_loss: 0.3677
# Epoch 22/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3879 - val_loss: 0.3725
# Epoch 23/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3644 - val_loss: 0.3590
# Epoch 24/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.3934 - val_loss: 0.3729
# Epoch 25/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3552 - val_loss: 0.3312
# Epoch 26/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3635 - val_loss: 0.3295
# Epoch 27/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3109 - val_loss: 0.2978
# Epoch 28/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2841 - val_loss: 0.2671
# Epoch 29/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3168 - val_loss: 0.3066
# Epoch 30/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3065 - val_loss: 0.2916
# Epoch 31/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2819 - val_loss: 0.2754
# Epoch 32/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.3037 - val_loss: 0.2889
# Epoch 33/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2737 - val_loss: 0.2673
# Epoch 34/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2811 - val_loss: 0.2724
# Epoch 35/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2904 - val_loss: 0.3081
# Epoch 36/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2744 - val_loss: 0.2770
# Epoch 37/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2547 - val_loss: 0.2515
# Epoch 38/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2666 - val_loss: 0.2614
# Epoch 39/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2903 - val_loss: 0.2682
# Epoch 40/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2719 - val_loss: 0.2837
# Epoch 41/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2845 - val_loss: 0.2832
# Epoch 42/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2871 - val_loss: 0.2638
# Epoch 43/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2626 - val_loss: 0.2461
# Epoch 44/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2828 - val_loss: 0.2725
# Epoch 45/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2480 - val_loss: 0.2655
# Epoch 46/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2634 - val_loss: 0.2427
# Epoch 47/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2391 - val_loss: 0.2347
# Epoch 48/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2452 - val_loss: 0.2473
# Epoch 49/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2550 - val_loss: 0.2477
# Epoch 50/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2464 - val_loss: 0.2381
# Epoch 51/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2433 - val_loss: 0.2391
# Epoch 52/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2641 - val_loss: 0.2796
# Epoch 53/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2670 - val_loss: 0.2559
# Epoch 54/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2453 - val_loss: 0.2320
# Epoch 55/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2390 - val_loss: 0.2212
# Epoch 56/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2408 - val_loss: 0.2316
# Epoch 57/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2404 - val_loss: 0.2295
# Epoch 58/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2509 - val_loss: 0.2551
# Epoch 59/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2393 - val_loss: 0.2366
# Epoch 60/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2396 - val_loss: 0.2433
# Epoch 61/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2259 - val_loss: 0.2231
# Epoch 62/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2609 - val_loss: 0.2417
# Epoch 63/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2340 - val_loss: 0.2176
# Epoch 64/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2209 - val_loss: 0.2117
# Epoch 65/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2223 - val_loss: 0.2119
# Epoch 66/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2713 - val_loss: 0.2519
# Epoch 67/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2421 - val_loss: 0.2252
# Epoch 68/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2477 - val_loss: 0.2437
# Epoch 69/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2330 - val_loss: 0.2239
# Epoch 70/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2322 - val_loss: 0.2235
# Epoch 71/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2364 - val_loss: 0.2213
# Epoch 72/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2291 - val_loss: 0.2262
# Epoch 73/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2378 - val_loss: 0.2464
# Epoch 74/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2272 - val_loss: 0.2266
# Epoch 75/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2226 - val_loss: 0.2131
# Epoch 76/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2251 - val_loss: 0.2171
# Epoch 77/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2545 - val_loss: 0.2468
# Epoch 78/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2392 - val_loss: 0.2347
# Epoch 79/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2255 - val_loss: 0.2197
# Epoch 80/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2265 - val_loss: 0.2192
# Epoch 81/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2251 - val_loss: 0.2219
# Epoch 82/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2159 - val_loss: 0.2106
# Epoch 83/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2187 - val_loss: 0.2135
# Epoch 84/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2275 - val_loss: 0.2204
# Epoch 85/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2083 - val_loss: 0.2034
# Epoch 86/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2161 - val_loss: 0.2151
# Epoch 87/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2262 - val_loss: 0.2155
# Epoch 88/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2077 - val_loss: 0.2126
# Epoch 89/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2213 - val_loss: 0.2157
# Epoch 90/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2218 - val_loss: 0.2132
# Epoch 91/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2226 - val_loss: 0.2199
# Epoch 92/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2342 - val_loss: 0.2359
# Epoch 93/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2155 - val_loss: 0.2071
# Epoch 94/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2133 - val_loss: 0.2052
# Epoch 95/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2282 - val_loss: 0.2209
# Epoch 96/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2089 - val_loss: 0.1983
# Epoch 97/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2005 - val_loss: 0.2003
# Epoch 98/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2160 - val_loss: 0.2033
# Epoch 99/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2137 - val_loss: 0.2090
# Epoch 100/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2307 - val_loss: 0.2240
# Epoch 101/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2000 - val_loss: 0.1897
# Epoch 102/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1833 - val_loss: 0.1780
# Epoch 103/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1902 - val_loss: 0.1855
# Epoch 104/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1974 - val_loss: 0.1921
# Epoch 105/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.2003 - val_loss: 0.2074
# Epoch 106/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1866 - val_loss: 0.1750
# Epoch 107/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1872 - val_loss: 0.1852
# Epoch 108/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1807 - val_loss: 0.1739
# Epoch 109/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1752 - val_loss: 0.1662
# Epoch 110/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1790 - val_loss: 0.1705
# Epoch 111/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1537 - val_loss: 0.1441
# Epoch 112/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1441 - val_loss: 0.1434
# Epoch 113/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1410 - val_loss: 0.1384
# Epoch 114/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1412 - val_loss: 0.1498
# Epoch 115/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1416 - val_loss: 0.1290
# Epoch 116/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1314 - val_loss: 0.1281
# Epoch 117/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1223 - val_loss: 0.1197
# Epoch 118/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1221 - val_loss: 0.1152
# Epoch 119/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1144 - val_loss: 0.1145
# Epoch 120/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1333 - val_loss: 0.1380
# Epoch 121/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1270 - val_loss: 0.1197
# Epoch 122/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1109 - val_loss: 0.1118
# Epoch 123/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1309 - val_loss: 0.1282
# Epoch 124/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1158 - val_loss: 0.1158
# Epoch 125/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1118 - val_loss: 0.1086
# Epoch 126/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1093 - val_loss: 0.1058
# Epoch 127/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1120 - val_loss: 0.1082
# Epoch 128/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1086 - val_loss: 0.1050
# Epoch 129/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1062 - val_loss: 0.1075
# Epoch 130/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.1039 - val_loss: 0.1016
# Epoch 131/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1058 - val_loss: 0.1037
# Epoch 132/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1100 - val_loss: 0.1057
# Epoch 133/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1155 - val_loss: 0.1277
# Epoch 134/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1016 - val_loss: 0.0910
# Epoch 135/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1065 - val_loss: 0.1112
# Epoch 136/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.1187 - val_loss: 0.1186
# Epoch 137/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0910 - val_loss: 0.0820
# Epoch 138/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0844 - val_loss: 0.0887
# Epoch 139/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0912 - val_loss: 0.0884
# Epoch 140/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0980 - val_loss: 0.0933
# Epoch 141/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0808 - val_loss: 0.0698
# Epoch 142/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0828 - val_loss: 0.0765
# Epoch 143/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0714 - val_loss: 0.0744
# Epoch 144/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0830 - val_loss: 0.0812
# Epoch 145/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0915 - val_loss: 0.0901
# Epoch 146/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0744 - val_loss: 0.0759
# Epoch 147/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0750 - val_loss: 0.0700
# Epoch 148/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0673 - val_loss: 0.0650
# Epoch 149/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0782 - val_loss: 0.1157
# Epoch 150/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0715 - val_loss: 0.0742
# Epoch 151/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0744 - val_loss: 0.0756
# Epoch 152/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0696 - val_loss: 0.0662
# Epoch 153/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0661 - val_loss: 0.0624
# Epoch 154/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0770 - val_loss: 0.0733
# Epoch 155/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0688 - val_loss: 0.0674
# Epoch 156/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0590 - val_loss: 0.0517
# Epoch 157/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0642 - val_loss: 0.0840
# Epoch 158/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0655 - val_loss: 0.0568
# Epoch 159/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0551 - val_loss: 0.0526
# Epoch 160/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0576 - val_loss: 0.0519
# Epoch 161/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0582 - val_loss: 0.0549
# Epoch 162/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0537 - val_loss: 0.0506
# Epoch 163/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0571 - val_loss: 0.0677
# Epoch 164/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0642 - val_loss: 0.0639
# Epoch 165/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0607 - val_loss: 0.0685
# Epoch 166/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0712 - val_loss: 0.0617
# Epoch 167/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0665 - val_loss: 0.0566
# Epoch 168/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0514 - val_loss: 0.0464
# Epoch 169/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0574 - val_loss: 0.0548
# Epoch 170/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0670 - val_loss: 0.0691
# Epoch 171/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0602 - val_loss: 0.0621
# Epoch 172/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0555 - val_loss: 0.0492
# Epoch 173/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0548 - val_loss: 0.0512
# Epoch 174/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0714 - val_loss: 0.0581
# Epoch 175/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0510 - val_loss: 0.0471
# Epoch 176/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0776 - val_loss: 0.0809
# Epoch 177/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0591 - val_loss: 0.0475
# Epoch 178/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0502 - val_loss: 0.0476
# Epoch 179/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0474 - val_loss: 0.0485
# Epoch 180/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0553 - val_loss: 0.0459
# Epoch 181/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0501 - val_loss: 0.0483
# Epoch 182/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0429 - val_loss: 0.0429
# Epoch 183/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0517 - val_loss: 0.0547
# Epoch 184/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0474 - val_loss: 0.0447
# Epoch 185/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0440 - val_loss: 0.0465
# Epoch 186/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0578 - val_loss: 0.0529
# Epoch 187/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0467 - val_loss: 0.0436
# Epoch 188/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0451 - val_loss: 0.0414
# Epoch 189/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0497 - val_loss: 0.0432
# Epoch 190/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0506 - val_loss: 0.0596
# Epoch 191/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0461 - val_loss: 0.0437
# Epoch 192/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0526 - val_loss: 0.0510
# Epoch 193/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0507 - val_loss: 0.0491
# Epoch 194/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0479 - val_loss: 0.0451
# Epoch 195/200
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0503 - val_loss: 0.0490
# Epoch 196/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0459 - val_loss: 0.0458
# Epoch 197/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0454 - val_loss: 0.0422
# Epoch 198/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0439 - val_loss: 0.0427
# Epoch 199/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0484 - val_loss: 0.0452
# Epoch 200/200
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0472 - val_loss: 0.0445

# %%
a = dg_train.__getitem__(8)[0]
plt.imshow(a[0,11,:,:,0])
plt.show()

# %%
result = model(np.expand_dims(a[0], axis=0)).numpy()
result.shape
# Out:
# (1, 12, 40, 40, 1)

# %%
plt.imshow((result[0,11,:,:,0]))
plt.show()

# %%
test_data = z_train.sel(time=slice('1979-05-01T16:00:00','1979-05-02T03:00:00' ),level = slice(1),longitude=slice(6,15.75), latitude=slice(55.5,45.75))
test_data = test_data.transpose('time', 'latitude', 'longitude', 'level')
# Normalize
mean = test_data['t'].mean(('time', 'latitude', 'longitude')).compute()
std = test_data['t'].std('time').mean(('latitude', 'longitude')).compute() 
test_data = (test_data['t'] - mean) / std
test_data = np.expand_dims(test_data.values, axis=0)
test_data.shape
# Out:
# (1, 12, 40, 40, 1)

# %% [markdown]
# ## Results
#
# Original:

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = test_data[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# Decompressed:

# %%
result2 = model(test_data).numpy()
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = result2[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# There is a difference between Model 4 and Model 4-2, we can see that the network is now predicting the first images better than the last ones, in model 4 it was the opposite.
