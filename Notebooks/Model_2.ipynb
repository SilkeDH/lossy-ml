# %% [markdown]
# ## Model 2
#
# This model doubles the CP from model 1. For that we will use less filters. In this case the CP is ((2^3)^2) / 10 = 6.4.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from collections import OrderedDict
from DataLoader import DataGenerator

# %%
model = models.Sequential()
model.add(layers.Conv3D(5, (4, 4, 4), activation='relu', strides=2, input_shape=(12, 40, 40, 1), padding="same", data_format = "channels_last"))
model.add(layers.Conv3D(10, (4, 4, 4), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(5, (4, 4, 4), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(1, (4, 4, 4), strides=2, padding="same", activation = None))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 6, 20, 20, 5)      325
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 3, 10, 10, 10)     3210
# _________________________________________________________________
# conv3d_transpose (Conv3DTran (None, 6, 20, 20, 5)      3205
# _________________________________________________________________
# conv3d_transpose_1 (Conv3DTr (None, 12, 40, 40, 1)     321
# =================================================================
# Total params: 7,061
# Trainable params: 7,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.MeanSquaredError())

# %%
months = 10
files = set('/lsdf/kit/scc/projects/abcde/1979/0'+str(i)+'/ERA5.pl.temperature.nc' for i in range(1,months))
z_train = xr.open_mfdataset(files, combine='by_coords')

bs=10 # batch size (from paper above)
dic = OrderedDict({'t': 1})  # Choosing first pressure level from variable temperature.
chunk_time = 12

#Define train and test datasets.
dg_train = DataGenerator(z_train.sel(time=slice('1979'), longitude=slice(6,15.75), latitude=slice(55.5,45.75)), dic, chunk_time, batch_size=bs, load=True, shuffle=True)
# Out:
# Loading data into RAM

# %%
history = model.fit(dg_train, validation_data = dg_train, epochs=100)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 1s 10ms/step - loss: 0.8726 - val_loss: 0.6216
# Epoch 2/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3798 - val_loss: 0.2561
# Epoch 3/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.1959 - val_loss: 0.1514
# Epoch 4/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.1458 - val_loss: 0.1282
# Epoch 5/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.1237 - val_loss: 0.1150
# Epoch 6/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.1032 - val_loss: 0.0903
# Epoch 7/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0792 - val_loss: 0.0717
# Epoch 8/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0684 - val_loss: 0.0619
# Epoch 9/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0588 - val_loss: 0.0502
# Epoch 10/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0497 - val_loss: 0.0447
# Epoch 11/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0459 - val_loss: 0.0480
# Epoch 12/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0371 - val_loss: 0.0332
# Epoch 13/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0334 - val_loss: 0.0308
# Epoch 14/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0347 - val_loss: 0.0301
# Epoch 15/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0293 - val_loss: 0.0255
# Epoch 16/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0244 - val_loss: 0.0235
# Epoch 17/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0239 - val_loss: 0.0209
# Epoch 18/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0208 - val_loss: 0.0197
# Epoch 19/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0228 - val_loss: 0.0189
# Epoch 20/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0201 - val_loss: 0.0179
# Epoch 21/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0217 - val_loss: 0.0433
# Epoch 22/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0216 - val_loss: 0.0193
# Epoch 23/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0170 - val_loss: 0.0157
# Epoch 24/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0151
# Epoch 25/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0146 - val_loss: 0.0144
# Epoch 26/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0152 - val_loss: 0.0151
# Epoch 27/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0131 - val_loss: 0.0134
# Epoch 28/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0146 - val_loss: 0.0142
# Epoch 29/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0138 - val_loss: 0.0128
# Epoch 30/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0134 - val_loss: 0.0136
# Epoch 31/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0113
# Epoch 32/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0234 - val_loss: 0.0200
# Epoch 33/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0147 - val_loss: 0.0130
# Epoch 34/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 35/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0112
# Epoch 36/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0114
# Epoch 37/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0103 - val_loss: 0.0101
# Epoch 38/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0100
# Epoch 39/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0164
# Epoch 40/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0125 - val_loss: 0.0108
# Epoch 41/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0103 - val_loss: 0.0098
# Epoch 42/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0099 - val_loss: 0.0199
# Epoch 43/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0141 - val_loss: 0.0244
# Epoch 44/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0192 - val_loss: 0.0129
# Epoch 45/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0116 - val_loss: 0.0098
# Epoch 46/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0099 - val_loss: 0.0097
# Epoch 47/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0093 - val_loss: 0.0092
# Epoch 48/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0083
# Epoch 49/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 50/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0081
# Epoch 51/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 52/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0097
# Epoch 53/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0088
# Epoch 54/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0205 - val_loss: 0.0132
# Epoch 55/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0098 - val_loss: 0.0083
# Epoch 56/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0118
# Epoch 57/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0119
# Epoch 58/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0105 - val_loss: 0.0090
# Epoch 59/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 60/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 61/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0101 - val_loss: 0.0110
# Epoch 62/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0093 - val_loss: 0.0092
# Epoch 63/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0075 - val_loss: 0.0069
# Epoch 64/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 65/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 66/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0084
# Epoch 67/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0105 - val_loss: 0.0076
# Epoch 68/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 69/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 70/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 71/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 72/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0131 - val_loss: 0.0220
# Epoch 73/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0439 - val_loss: 0.0267
# Epoch 74/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0079
# Epoch 75/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0069
# Epoch 76/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0066
# Epoch 77/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 78/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 79/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 80/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 81/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 82/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 83/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 84/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 85/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 86/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 87/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0081
# Epoch 88/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 89/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 90/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 91/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 92/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 93/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 94/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 95/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0057
# Epoch 96/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 97/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 98/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 99/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 100/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0086

# %%
a = dg_train.__getitem__(8)[0]
plt.imshow(a[0,11,:,:,0])
plt.show()

# %%
result = model(np.expand_dims(a[0], axis=0)).numpy()

# %%
plt.imshow((result[0,11,:,:,0]))
plt.show()

# %%
test_data = z_train.sel(time=slice('1979-05-01T16:00:00','1979-05-02T03:00:00' ),level = slice(1),longitude=slice(6,15.75), latitude=slice(55.5,45.75))
test_data = test_data.transpose('time', 'latitude', 'longitude', 'level')
# Normalize
mean = test_data['t'].mean(('time', 'latitude', 'longitude')).compute()
std = test_data['t'].std('time').mean(('latitude', 'longitude')).compute() 
test_data = (test_data['t'] - mean) / std
test_data = np.expand_dims(test_data.values, axis=0)
test_data.shape
# Out:
# (1, 12, 40, 40, 1)

# %% [markdown]
# ## Results
#
# Original:

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = test_data[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# Decompressed:

# %%
result2 = model(test_data).numpy()
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = result2[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# It's not a surprise we don't get such good results as before. How can we increase the CP without deteriorating the quality of our output?
