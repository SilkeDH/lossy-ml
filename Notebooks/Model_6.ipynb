# %% [markdown]
# ## Model 6
#
# This model has 4 residual blocks and 2 compression blocks. CP = (2^3)^2 / 8 = 8.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from collections import OrderedDict
from DataLoader import DataGenerator

# %%
import tensorflow as tf
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv3D, ReLU, LeakyReLU, BatchNormalization,\
                                    Add, Flatten, Dense, Conv3DTranspose
from tensorflow.keras.models import Model


def residual_block(x: Tensor, filters: int, kernel_size = (3, 3, 3)) -> Tensor:
    y = Conv3D(kernel_size=kernel_size, strides= 1, filters=filters, padding="same")(x)
    y = ReLU()(x)
    y = Conv3D(kernel_size=kernel_size, strides=1, filters=filters, padding="same")(y)
    return y

def encoder(x: Tensor):
    kernel_size = (3, 3, 3)
    C = 4
    num_res_blocks = 4
    num_comp_lay = 2
    
    x = Conv3D(kernel_size=kernel_size, strides=1, filters=C, padding="same")(x)
    x = LeakyReLU(alpha=0.2)(x)

    first_skip_conn = x
    
    for j in range(num_res_blocks):
        skip_connection = x
        x = residual_block(x, filters=C)
        x = Add()([skip_connection, x])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C, padding="same")(x)
    x = Add()([first_skip_conn, x])
    
    C_mult = [2, 1]
    
    for i in range(num_comp_lay):
        C = int(x.get_shape()[-1])
        x = Conv3D(kernel_size=kernel_size, strides= 2, filters=C, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C_mult[i]*C, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)

        
    C = int(x.get_shape()[-1])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=int(C/2), padding="same")(x)

    return x

def decoder(x: Tensor):
    kernel_size = (3, 3, 3)
    num_res_blocks = 4
    nump_comp_lay = 2
    C = int(x.get_shape()[-1])
    
    x = Conv3D(kernel_size=kernel_size, strides=1, filters=2*C,padding="same")(x)
    
    C_div = [1, 2]
    
    for i in range(nump_comp_lay):
        C = int(x.get_shape()[-1])
        C_over_div = int(int(C)/C_div[i])
        x = Conv3D(kernel_size=kernel_size,strides= 1,filters=C_over_div, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv3DTranspose(C_over_div, kernel_size=kernel_size, strides=2, padding="same")(x)
        x = LeakyReLU(alpha=0.2)(x)

    skip_connection = x
    
    C = 4

    for i in range(num_res_blocks):
        B_skip_connection = x
        x = residual_block(x, filters=C)
        x = Add()([B_skip_connection, x])
        
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters=C, padding="same")(x)
    x = Add()([skip_connection, x])
    
    x = Conv3D(kernel_size=kernel_size, strides= 1, filters= 1, padding="same")(x)

    return x

def Autoencoder():
    
    inputs = Input(shape=(32, 40, 40, 1))
    
    enc = encoder(inputs)
    dec = decoder(enc)
    
    model = Model(inputs, dec)

    model.compile(
        optimizer= keras.optimizers.Adam(learning_rate=0.001),
        loss=tf.keras.losses.MeanSquaredError(),
    )

    return model

# %%
model = Autoencoder() 
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 32, 40, 40,  0
# __________________________________________________________________________________________________
# conv3d_94 (Conv3D)              (None, 32, 40, 40, 4 112         input_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 32, 40, 40, 4 0           conv3d_94[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 32, 40, 40, 4 0           leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# conv3d_96 (Conv3D)              (None, 32, 40, 40, 4 436         re_lu_32[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 32, 40, 40, 4 0           leaky_re_lu_26[0][0]
#                                                                  conv3d_96[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 32, 40, 40, 4 0           add_36[0][0]
# __________________________________________________________________________________________________
# conv3d_98 (Conv3D)              (None, 32, 40, 40, 4 436         re_lu_33[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 32, 40, 40, 4 0           add_36[0][0]
#                                                                  conv3d_98[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 32, 40, 40, 4 0           add_37[0][0]
# __________________________________________________________________________________________________
# conv3d_100 (Conv3D)             (None, 32, 40, 40, 4 436         re_lu_34[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 32, 40, 40, 4 0           add_37[0][0]
#                                                                  conv3d_100[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 32, 40, 40, 4 0           add_38[0][0]
# __________________________________________________________________________________________________
# conv3d_102 (Conv3D)             (None, 32, 40, 40, 4 436         re_lu_35[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 32, 40, 40, 4 0           add_38[0][0]
#                                                                  conv3d_102[0][0]
# __________________________________________________________________________________________________
# conv3d_103 (Conv3D)             (None, 32, 40, 40, 4 436         add_39[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 32, 40, 40, 4 0           leaky_re_lu_26[0][0]
#                                                                  conv3d_103[0][0]
# __________________________________________________________________________________________________
# conv3d_104 (Conv3D)             (None, 16, 20, 20, 4 436         add_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 16, 20, 20, 4 0           conv3d_104[0][0]
# __________________________________________________________________________________________________
# conv3d_105 (Conv3D)             (None, 16, 20, 20, 8 872         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 16, 20, 20, 8 0           conv3d_105[0][0]
# __________________________________________________________________________________________________
# conv3d_106 (Conv3D)             (None, 8, 10, 10, 8) 1736        leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 8, 10, 10, 8) 0           conv3d_106[0][0]
# __________________________________________________________________________________________________
# conv3d_107 (Conv3D)             (None, 8, 10, 10, 8) 1736        leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 8, 10, 10, 8) 0           conv3d_107[0][0]
# __________________________________________________________________________________________________
# conv3d_108 (Conv3D)             (None, 8, 10, 10, 4) 868         leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# conv3d_109 (Conv3D)             (None, 8, 10, 10, 8) 872         conv3d_108[0][0]
# __________________________________________________________________________________________________
# conv3d_110 (Conv3D)             (None, 8, 10, 10, 8) 1736        conv3d_109[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 8, 10, 10, 8) 0           conv3d_110[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_6 (Conv3DTrans (None, 16, 20, 20, 8 1736        leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 16, 20, 20, 8 0           conv3d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv3d_111 (Conv3D)             (None, 16, 20, 20, 4 868         leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 16, 20, 20, 4 0           conv3d_111[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_7 (Conv3DTrans (None, 32, 40, 40, 4 436         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 32, 40, 40, 4 0           conv3d_transpose_7[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 32, 40, 40, 4 0           leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# conv3d_113 (Conv3D)             (None, 32, 40, 40, 4 436         re_lu_36[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 32, 40, 40, 4 0           leaky_re_lu_34[0][0]
#                                                                  conv3d_113[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 32, 40, 40, 4 0           add_41[0][0]
# __________________________________________________________________________________________________
# conv3d_115 (Conv3D)             (None, 32, 40, 40, 4 436         re_lu_37[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 32, 40, 40, 4 0           add_41[0][0]
#                                                                  conv3d_115[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 32, 40, 40, 4 0           add_42[0][0]
# __________________________________________________________________________________________________
# conv3d_117 (Conv3D)             (None, 32, 40, 40, 4 436         re_lu_38[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 32, 40, 40, 4 0           add_42[0][0]
#                                                                  conv3d_117[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 32, 40, 40, 4 0           add_43[0][0]
# __________________________________________________________________________________________________
# conv3d_119 (Conv3D)             (None, 32, 40, 40, 4 436         re_lu_39[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 32, 40, 40, 4 0           add_43[0][0]
#                                                                  conv3d_119[0][0]
# __________________________________________________________________________________________________
# conv3d_120 (Conv3D)             (None, 32, 40, 40, 4 436         add_44[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 32, 40, 40, 4 0           leaky_re_lu_34[0][0]
#                                                                  conv3d_120[0][0]
# __________________________________________________________________________________________________
# conv3d_121 (Conv3D)             (None, 32, 40, 40, 1 109         add_45[0][0]
# ==================================================================================================
# Total params: 15,877
# Trainable params: 15,877
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#months = 10
#files = set('/lsdf/kit/scc/projects/abcde/1979/0'+str(i)+'/ERA5.pl.temperature.nc' for i in range(1,months))
z_train = xr.open_mfdataset('/lsdf/kit/scc/projects/abcde/1979/*/ERA5.pl.temperature.nc', combine='by_coords')

bs=10 # batch size (from paper above)
dic = OrderedDict({'t': 1})  # Choosing first pressure level from variable temperature.
chunk_time = 32

#Define train and test datasets.
dg_train = DataGenerator(z_train.sel(time=slice('1979'), longitude=slice(6,15.75), latitude=slice(55.5,45.75)), dic, chunk_time, batch_size=bs, load=True, shuffle=True)
# Out:
# Loading data into RAM

# %%
history = model.fit(dg_train, validation_data = dg_train, epochs=200)
# Out:
# Epoch 1/200
#  2/28 [=>............................] - ETA: 1s - loss: 0.0595WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0152s vs `on_train_batch_end` time: 0.0452s). Check your callbacks.
# 28/28 [==============================] - 2s 70ms/step - loss: 0.0509 - val_loss: 0.0505
# Epoch 2/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0490 - val_loss: 0.0574
# Epoch 3/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0568 - val_loss: 0.0539
# Epoch 4/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0551 - val_loss: 0.0537
# Epoch 5/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0441 - val_loss: 0.0450
# Epoch 6/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0492 - val_loss: 0.0477
# Epoch 7/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0537 - val_loss: 0.0558
# Epoch 8/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0531 - val_loss: 0.0502
# Epoch 9/200
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0541 - val_loss: 0.0542
# Epoch 10/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0569 - val_loss: 0.0541
# Epoch 11/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0528 - val_loss: 0.0635
# Epoch 12/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0554 - val_loss: 0.0490
# Epoch 13/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0546 - val_loss: 0.0555
# Epoch 14/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0617 - val_loss: 0.0562
# Epoch 15/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0537 - val_loss: 0.0505
# Epoch 16/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0544 - val_loss: 0.0539
# Epoch 17/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0526 - val_loss: 0.0502
# Epoch 18/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0461 - val_loss: 0.0480
# Epoch 19/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0466 - val_loss: 0.0492
# Epoch 20/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0517 - val_loss: 0.0529
# Epoch 21/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0487 - val_loss: 0.0479
# Epoch 22/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0517 - val_loss: 0.0501
# Epoch 23/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0473 - val_loss: 0.0479
# Epoch 24/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0481 - val_loss: 0.0471
# Epoch 25/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0475 - val_loss: 0.0442
# Epoch 26/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0502 - val_loss: 0.0480
# Epoch 27/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0482 - val_loss: 0.0462
# Epoch 28/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0499 - val_loss: 0.0492
# Epoch 29/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0487 - val_loss: 0.0504
# Epoch 30/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0464 - val_loss: 0.0426
# Epoch 31/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0479 - val_loss: 0.0463
# Epoch 32/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0469 - val_loss: 0.0489
# Epoch 33/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0617 - val_loss: 0.0673
# Epoch 34/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0519 - val_loss: 0.0452
# Epoch 35/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0566 - val_loss: 0.0565
# Epoch 36/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0492 - val_loss: 0.0460
# Epoch 37/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0467 - val_loss: 0.0479
# Epoch 38/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0448 - val_loss: 0.0424
# Epoch 39/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0503 - val_loss: 0.0501
# Epoch 40/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0468 - val_loss: 0.0479
# Epoch 41/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0439 - val_loss: 0.0421
# Epoch 42/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0478 - val_loss: 0.0481
# Epoch 43/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0480 - val_loss: 0.0464
# Epoch 44/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0423 - val_loss: 0.0428
# Epoch 45/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0484 - val_loss: 0.0473
# Epoch 46/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0545 - val_loss: 0.0517
# Epoch 47/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0500 - val_loss: 0.0503
# Epoch 48/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0472 - val_loss: 0.0433
# Epoch 49/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0491 - val_loss: 0.0493
# Epoch 50/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0533 - val_loss: 0.0648
# Epoch 51/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0533 - val_loss: 0.0449
# Epoch 52/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0583 - val_loss: 0.0534
# Epoch 53/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0547 - val_loss: 0.0528
# Epoch 54/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0496 - val_loss: 0.0462
# Epoch 55/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0457 - val_loss: 0.0446
# Epoch 56/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0395 - val_loss: 0.0361
# Epoch 57/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0417 - val_loss: 0.0431
# Epoch 58/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0517 - val_loss: 0.0593
# Epoch 59/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0473 - val_loss: 0.0436
# Epoch 60/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0447 - val_loss: 0.0397
# Epoch 61/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0440 - val_loss: 0.0449
# Epoch 62/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0421 - val_loss: 0.0432
# Epoch 63/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0402 - val_loss: 0.0401
# Epoch 64/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0438 - val_loss: 0.0492
# Epoch 65/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0405 - val_loss: 0.0376
# Epoch 66/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0401 - val_loss: 0.0390
# Epoch 67/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0402 - val_loss: 0.0420
# Epoch 68/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0382 - val_loss: 0.0351
# Epoch 69/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0446 - val_loss: 0.0433
# Epoch 70/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0416 - val_loss: 0.0409
# Epoch 71/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0502 - val_loss: 0.0443
# Epoch 72/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0399 - val_loss: 0.0369
# Epoch 73/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0386 - val_loss: 0.0386
# Epoch 74/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0448 - val_loss: 0.0412
# Epoch 75/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0426 - val_loss: 0.0407
# Epoch 76/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0373 - val_loss: 0.0362
# Epoch 77/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0377 - val_loss: 0.0332
# Epoch 78/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0347 - val_loss: 0.0372
# Epoch 79/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0368 - val_loss: 0.0365
# Epoch 80/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0364 - val_loss: 0.0359
# Epoch 81/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0372 - val_loss: 0.0335
# Epoch 82/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0342 - val_loss: 0.0332
# Epoch 83/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0404 - val_loss: 0.0455
# Epoch 84/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0375 - val_loss: 0.0343
# Epoch 85/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0405 - val_loss: 0.0394
# Epoch 86/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0379 - val_loss: 0.0397
# Epoch 87/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0382 - val_loss: 0.0379
# Epoch 88/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0387 - val_loss: 0.0373
# Epoch 89/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0351 - val_loss: 0.0349
# Epoch 90/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0341 - val_loss: 0.0406
# Epoch 91/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0419 - val_loss: 0.0394
# Epoch 92/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0373 - val_loss: 0.0337
# Epoch 93/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0390 - val_loss: 0.0440
# Epoch 94/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0383 - val_loss: 0.0355
# Epoch 95/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0390 - val_loss: 0.0424
# Epoch 96/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0323 - val_loss: 0.0303
# Epoch 97/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0351 - val_loss: 0.0339
# Epoch 98/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0328 - val_loss: 0.0306
# Epoch 99/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0395 - val_loss: 0.0378
# Epoch 100/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0358 - val_loss: 0.0339
# Epoch 101/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0338 - val_loss: 0.0335
# Epoch 102/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0456 - val_loss: 0.0423
# Epoch 103/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0403 - val_loss: 0.0490
# Epoch 104/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0435 - val_loss: 0.0446
# Epoch 105/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0393 - val_loss: 0.0341
# Epoch 106/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0342 - val_loss: 0.0347
# Epoch 107/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0331 - val_loss: 0.0310
# Epoch 108/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0329 - val_loss: 0.0336
# Epoch 109/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0297 - val_loss: 0.0272
# Epoch 110/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0354 - val_loss: 0.0326
# Epoch 111/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0332 - val_loss: 0.0327
# Epoch 112/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0323 - val_loss: 0.0313
# Epoch 113/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0324 - val_loss: 0.0318
# Epoch 114/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0334 - val_loss: 0.0303
# Epoch 115/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0364 - val_loss: 0.0344
# Epoch 116/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0417 - val_loss: 0.0420
# Epoch 117/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0319 - val_loss: 0.0274
# Epoch 118/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0391 - val_loss: 0.0407
# Epoch 119/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0323 - val_loss: 0.0300
# Epoch 120/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0306 - val_loss: 0.0298
# Epoch 121/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0379 - val_loss: 0.0393
# Epoch 122/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0320 - val_loss: 0.0288
# Epoch 123/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0315 - val_loss: 0.0292
# Epoch 124/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0320 - val_loss: 0.0297
# Epoch 125/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0366 - val_loss: 0.0335
# Epoch 126/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0400 - val_loss: 0.0351
# Epoch 127/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0337 - val_loss: 0.0316
# Epoch 128/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0335 - val_loss: 0.0298
# Epoch 129/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0289 - val_loss: 0.0271
# Epoch 130/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0305 - val_loss: 0.0371
# Epoch 131/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0284 - val_loss: 0.0251
# Epoch 132/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0298 - val_loss: 0.0277
# Epoch 133/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0299 - val_loss: 0.0276
# Epoch 134/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0283 - val_loss: 0.0280
# Epoch 135/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0310 - val_loss: 0.0288
# Epoch 136/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0288 - val_loss: 0.0266
# Epoch 137/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0309 - val_loss: 0.0310
# Epoch 138/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0335 - val_loss: 0.0306
# Epoch 139/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0302 - val_loss: 0.0282
# Epoch 140/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0324 - val_loss: 0.0304
# Epoch 141/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0352 - val_loss: 0.0341
# Epoch 142/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0347 - val_loss: 0.0303
# Epoch 143/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0429 - val_loss: 0.0480
# Epoch 144/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0487 - val_loss: 0.0420
# Epoch 145/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0353 - val_loss: 0.0305
# Epoch 146/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0281 - val_loss: 0.0277
# Epoch 147/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0295 - val_loss: 0.0282
# Epoch 148/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0280 - val_loss: 0.0373
# Epoch 149/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0301 - val_loss: 0.0282
# Epoch 150/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0259 - val_loss: 0.0276
# Epoch 151/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0287 - val_loss: 0.0356
# Epoch 152/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0314 - val_loss: 0.0263
# Epoch 153/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0310 - val_loss: 0.0280
# Epoch 154/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0261 - val_loss: 0.0264
# Epoch 155/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0295 - val_loss: 0.0312
# Epoch 156/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0309 - val_loss: 0.0291
# Epoch 157/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0282 - val_loss: 0.0276
# Epoch 158/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0296 - val_loss: 0.0283
# Epoch 159/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0313 - val_loss: 0.0304
# Epoch 160/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0303 - val_loss: 0.0282
# Epoch 161/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0280 - val_loss: 0.0259
# Epoch 162/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0293 - val_loss: 0.0256
# Epoch 163/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0255 - val_loss: 0.0230
# Epoch 164/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0312 - val_loss: 0.0376
# Epoch 165/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0441 - val_loss: 0.0347
# Epoch 166/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0362 - val_loss: 0.0284
# Epoch 167/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0302 - val_loss: 0.0269
# Epoch 168/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0260 - val_loss: 0.0272
# Epoch 169/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0262 - val_loss: 0.0259
# Epoch 170/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0311 - val_loss: 0.0261
# Epoch 171/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0300 - val_loss: 0.0332
# Epoch 172/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0294 - val_loss: 0.0304
# Epoch 173/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0325 - val_loss: 0.0322
# Epoch 174/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0476 - val_loss: 0.0593
# Epoch 175/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0419 - val_loss: 0.0303
# Epoch 176/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0294 - val_loss: 0.0263
# Epoch 177/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0275 - val_loss: 0.0263
# Epoch 178/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0272 - val_loss: 0.0303
# Epoch 179/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0242 - val_loss: 0.0230
# Epoch 180/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0227 - val_loss: 0.0220
# Epoch 181/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0237 - val_loss: 0.0226
# Epoch 182/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0204 - val_loss: 0.0190
# Epoch 183/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0208 - val_loss: 0.0203
# Epoch 184/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0214 - val_loss: 0.0220
# Epoch 185/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0238 - val_loss: 0.0219
# Epoch 186/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0233 - val_loss: 0.0234
# Epoch 187/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0241 - val_loss: 0.0233
# Epoch 188/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0237 - val_loss: 0.0224
# Epoch 189/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0253 - val_loss: 0.0267
# Epoch 190/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0247 - val_loss: 0.0251
# Epoch 191/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0259 - val_loss: 0.0248
# Epoch 192/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0270 - val_loss: 0.0255
# Epoch 193/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0272 - val_loss: 0.0255
# Epoch 194/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0221 - val_loss: 0.0207
# Epoch 195/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0285 - val_loss: 0.0419
# Epoch 196/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0349 - val_loss: 0.0306
# Epoch 197/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0282 - val_loss: 0.0258
# Epoch 198/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0268 - val_loss: 0.0265
# Epoch 199/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0244 - val_loss: 0.0245
# Epoch 200/200
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0313 - val_loss: 0.0307

# %%
a = dg_train.__getitem__(8)[0]
plt.imshow(a[0,11,:,:,0])
plt.show()

# %%
result = model(np.expand_dims(a[0], axis=0)).numpy()
result.shape
# Out:
# (1, 32, 40, 40, 1)

# %%
plt.imshow((result[0,11,:,:,0]))
plt.show()

# %%
test_data = z_train.sel(time=slice('1979-05-01T16:00:00','1979-05-02T23:00:00' ),level = slice(1),longitude=slice(6,15.75), latitude=slice(55.5,45.75))
test_data = test_data.transpose('time', 'latitude', 'longitude', 'level')
# Normalize
mean = test_data['t'].mean(('time', 'latitude', 'longitude')).compute()
std = test_data['t'].std('time').mean(('latitude', 'longitude')).compute() 
test_data = (test_data['t'] - mean) / std
test_data = np.expand_dims(test_data.values, axis=0)
test_data.shape
# Out:
# (1, 32, 40, 40, 1)

# %% [markdown]
# ## Results
#
# Original:

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = test_data[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# Decompressed:

# %%
result2 = model(test_data).numpy()
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = result2[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# There is a difference between Model 4 and Model 4-2, we can see that the network is now predicting the first images better than the last ones, in model 4 it was the opposite.
