# %% [markdown]
# ## Model 1
#
# This first model consists of a simple 3D autoencoder with 2 conv3D and 2 conv3DTranspose. Compression ratio is (2^3)^2 = 64 divided across 20 filters, that would make: 64/20 = 3.2 = CP. It's a low ratio.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from collections import OrderedDict
from DataLoader import DataGenerator

# %%
model = models.Sequential()
model.add(layers.Conv3D(10, (4, 4, 4), activation='relu', strides=2, input_shape=(12, 40, 40, 1), padding="same", data_format = "channels_last"))
model.add(layers.Conv3D(20, (4, 4, 4), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(10, (4, 4, 4), strides=2, padding="same", activation='relu'))
model.add(layers.Conv3DTranspose(1, (4, 4, 4), strides=2, padding="same", activation = None))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_8 (Conv3D)            (None, 6, 20, 20, 10)     650
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 3, 10, 10, 20)     12820
# _________________________________________________________________
# conv3d_transpose_8 (Conv3DTr (None, 6, 20, 20, 10)     12810
# _________________________________________________________________
# conv3d_transpose_9 (Conv3DTr (None, 12, 40, 40, 1)     641
# =================================================================
# Total params: 26,921
# Trainable params: 26,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.MeanSquaredError())

# %%
months = 10
files = set('/lsdf/kit/scc/projects/abcde/1979/0'+str(i)+'/ERA5.pl.temperature.nc' for i in range(1,months))
z_train = xr.open_mfdataset(files, combine='by_coords')

bs=10 # batch size (from paper above)
dic = OrderedDict({'t': 1})  # Choosing first pressure level from variable temperature.
chunk_time = 12

#Define train and test datasets.
dg_train = DataGenerator(z_train.sel(time=slice('1979'), longitude=slice(6,15.75), latitude=slice(55.5,45.75)), dic, chunk_time, batch_size=bs, load=True, shuffle=True)
# Out:
# Loading data into RAM

# %%
history = model.fit(dg_train, validation_data = dg_train, epochs=100)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0222 - val_loss: 0.0080
# Epoch 2/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0051
# Epoch 3/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 4/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 5/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0078
# Epoch 6/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 7/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 8/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 9/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 10/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 11/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 12/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 13/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 14/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 15/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0073 - val_loss: 0.0055
# Epoch 16/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 17/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 18/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 19/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 20/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 21/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 22/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 23/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0050
# Epoch 24/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 25/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 26/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 27/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 28/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 29/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 30/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0066
# Epoch 31/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0171 - val_loss: 0.0083
# Epoch 32/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 33/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 34/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 35/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 36/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 37/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 38/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0069
# Epoch 39/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 40/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 41/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 42/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 43/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 44/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0143
# Epoch 45/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0028
# Epoch 46/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 47/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 48/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 49/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 50/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 51/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 52/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0051
# Epoch 53/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0089
# Epoch 54/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0156 - val_loss: 0.0052
# Epoch 55/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 56/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 57/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 58/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 59/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 60/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 61/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 62/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 63/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 64/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 65/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0033
# Epoch 66/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 67/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 68/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 69/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 70/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0046
# Epoch 71/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 72/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 73/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 74/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 75/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 76/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 77/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0056
# Epoch 78/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 79/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 80/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0128
# Epoch 81/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0114 - val_loss: 0.0045
# Epoch 82/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 83/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0039
# Epoch 84/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 85/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0033
# Epoch 86/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 87/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 88/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 89/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 90/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 91/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 92/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0081
# Epoch 93/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0141 - val_loss: 0.0044
# Epoch 94/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 95/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 96/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 97/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 98/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 99/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 100/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0019

# %%
a = dg_train.__getitem__(8)[0]
plt.imshow(a[0,10,:,:,0])
plt.show()

# %%
result = model(np.expand_dims(a[0], axis=0)).numpy()

# %%
plt.imshow((result[0,10,:,:,0]))
plt.show()

# %%
test_data = z_train.sel(time=slice('1979-05-01T16:00:00','1979-05-02T03:00:00' ),level = slice(1),longitude=slice(6,15.75), latitude=slice(55.5,45.75))
test_data = test_data.transpose('time', 'latitude', 'longitude', 'level')
# Normalize
mean = test_data['t'].mean(('time', 'latitude', 'longitude')).compute()
std = test_data['t'].std('time').mean(('latitude', 'longitude')).compute() 
test_data = (test_data['t'] - mean) / std
test_data = np.expand_dims(test_data.values, axis=0)
test_data.shape
# Out:
# (1, 12, 40, 40, 1)

# %% [markdown]
# ## Results
#
# Original:

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = test_data[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# Decompressed:

# %%
result2 = model(test_data).numpy()
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 3
for i in range(0, columns*rows):
    img = result2[0,i,:,:,0]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()
